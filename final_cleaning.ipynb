# %%
import pandas as pd
# create a dataframe

actors = pd.read_csv("actors2.csv", error_bad_lines=False)
# display the dataframe
actors
# Out:
# <ipython-input-13-5f3c1cbd58a4>:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   actors = pd.read_csv("actors2.csv", error_bad_lines=False)
# b'Skipping line 1105: expected 3 fields, saw 6\nSkipping line 1313: expected 3 fields, saw 7\nSkipping line 1754: expected 3 fields, saw 6\nSkipping line 2623: expected 3 fields, saw 5\nSkipping line 2866: expected 3 fields, saw 12\nSkipping line 2889: expected 3 fields, saw 6\nSkipping line 3008: expected 3 fields, saw 7\n'
#       index                           original_title  \
# 0      5246                               Religulous
# 1       816                              Bad Company
# 2       754                            The Lost City
# 3      4743                            Bottle Rocket
# 4      5379                       Inside Deep Throat
# ...     ...                                      ...
# ...

# %%
actors['starring'].str.split(',',expand=True)
# Out:
#                         0                 1                      2   \
# 0               Bill Maher              None                   None
# 1          Anthony Hopkins        Chris Rock          Gabriel Macht
# 2              Andy García    Dustin Hoffman            Bill Murray
# 3                      NaN               NaN                    NaN
# 4                      NaN               NaN                    NaN
# ...                    ...               ...                    ...
# 3255        Jason Yachanin       Kate Graham       Allyson Sereboff
# 3256             Tom Hanks      Barkhad Abdi                   None
# 3257     Leonardo DiCaprio      Ken Watanabe   Joseph Gordon-Levitt
# 3258     Jennifer Lawrence   Josh Hutcherson         Liam Hemsworth
# 3259  Aaron Taylor-Johnson      Ken Watanabe        Elizabeth Olsen
#
#                      3                 4                  5   \
# 0                  None              None               None
# ...

# %%
actors['primary actor'] = actors['starring'].str.split(',', expand=True)[0]

# %%
actors.head()
# Out:
#    index      original_title  \
# 0   5246          Religulous
# 1    816         Bad Company
# 2    754       The Lost City
# 3   4743       Bottle Rocket
# 4   5379  Inside Deep Throat
#
#                                             starring    primary actor
# 0                                         Bill Maher       Bill Maher
# 1         Anthony Hopkins, Chris Rock, Gabriel Macht  Anthony Hopkins
# 2  Andy García, Dustin Hoffman, Bill Murray, Inés...      Andy García
# 3                                                NaN              NaN
# 4                                                NaN              NaN

# %%
from sqlalchemy import create_engine

from config import db_password

db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/class_project_final"
engine = create_engine(db_string)
actors.to_sql(name='actors_clean', con=engine, if_exists='replace')
# Out:
# 260

# %%
import csv
import json

## initialize lists
fields = []
rows = []

outcsv = open('/Users/ajennings/Desktop/rutgers_bootcamp/Class_Project3/data_cleaning/movies_final2.csv', newline='', mode='w', encoding='utf8')
writeit = csv.writer(outcsv, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

inFile = open('/Users/ajennings/Desktop/rutgers_bootcamp/Class_Project3/data_cleaning/movies_final_ORG.csv', 'r', encoding="utf8")
readit = csv.reader(inFile)

try: 
    fields = next(readit)

except: 
    pass
    
for row in readit:
    rows.append(row)

## row 7 contains the list of dictionaries
    try:
        y = row[7]    
    except:
        pass

## skip processing if row[7] is empty
    if (y !=''):

## replace the single quote with a double quote so JSON can read it
        fixed_row = y.replace("''", '"')

## prepend and append stuff so that fixed_row looks like JSON
        json_row = ('{ "genre": ' + fixed_row + '}')
        json_obj = json.loads(json_row)

## initialize a list to hold the genre types
        rnames = []
        for gen in json_obj["genre"]:
            rnames.append(gen["name"])

## the stupid part; read the rnames into a NEW list or you'll end up adding a new column for each genre where there is more than 1 genre
        xtralist = []
        xtralist.append(rnames)
        row_list=(row[0:7]+xtralist+row[8:])
        writeit.writerow(row_list)

    else:
## if there were no genres, just rewrite the row
        writeit.writerow(row)
    
inFile.close()
outcsv.close()

# %%
outcsv = open('/Users/ajennings/Desktop/rutgers_bootcamp/Class_Project3/data_cleaning/movies_final.csv', 'w', encoding='utf8')
inFile = open('/Users/ajennings/Desktop/rutgers_bootcamp/Class_Project3/data_cleaning/movies_final2.csv', 'r', encoding="utf8")

for eachLine in inFile:
    w = eachLine.replace(',[', ',"')
    x = w.replace('],', '",')
    y = x.replace('[','')
    z = y.replace(']','')
    a = z.replace("'","")
    outcsv.write(a)

inFile.close()
outcsv.close()

# %%
# read contents of csv file
df = pd.read_csv("/Users/ajennings/Desktop/rutgers_bootcamp/Class_Project3/data_cleaning/movies_final.csv", header=None,error_bad_lines=False)
df.head()
# Out:
# <ipython-input-39-5ee4db810d4d>:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("/Users/ajennings/Desktop/rutgers_bootcamp/Class_Project3/data_cleaning/movies_final.csv", header=None,error_bad_lines=False)
# b'Skipping line 246: expected 10 fields, saw 12\nSkipping line 475: expected 10 fields, saw 13\nSkipping line 633: expected 10 fields, saw 12\nSkipping line 775: expected 10 fields, saw 11\nSkipping line 954: expected 10 fields, saw 11\nSkipping line 1309: expected 10 fields, saw 11\nSkipping line 1890: expected 10 fields, saw 11\nSkipping line 3155: expected 10 fields, saw 11\nSkipping line 3239: expected 10 fields, saw 13\n'
#      0                                    1          2          3          4  \
# 0   15                              Tangled  260000000  584899819  tt0398286
# 1   37                       Men in Black 3  215000000  654213485  tt1409024
# ...

# %%
#split genre to have only one genre listed
df[7] = df[7].str.split(',', expand=True)[0]

# %%
df.head()
# Out:
#      0                                    1          2          3          4  \
# 0   15                              Tangled  260000000  584899819  tt0398286
# 1   37                       Men in Black 3  215000000  654213485  tt1409024
# 2  759                               Sphere   73000000   50168294  tt0120184
# 3  186                         Transformers  151000000  708272592  tt0418279
# 4   38  Transformers: Revenge of the Fallen  210000000  836519699  tt1055369
#
#              5            6                7                           8  \
# 0  260000000.0  591794936.0        Animation  Nathan Greno, Byron Howard
# 1  225000000.0  624026776.0           Action            Barry Sonnenfeld
# 2   75000000.0   13100000.0  Science Fiction              Barry Levinson
# 3  150000000.0  709709780.0        Adventure                 Michael Bay
# 4  150000000.0  836297228.0  Science Fiction                 Michael Bay
#
#                 9
# 0     Mandy Moore
# 1      Will Smith
# ...

# %%
df.shape
# Out:
# (3669, 10)

# %%
df = df.dropna()
df.shape
# Out:
# (3479, 10)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (3215, 10)

# %%
df.to_csv('/Users/ajennings/Desktop/rutgers_bootcamp/Class_Project3/data_cleaning/movies_final_final.csv', index = False, header=True)

# %%
# read contents of csv file
file = pd.read_csv("/Users/ajennings/Desktop/rutgers_bootcamp/Class_Project3/data_cleaning/movies_final_final.csv")

  
# adding header
headerList = ['index','original_title','production_budget','worldwide_gross','imdb_id','budget','revenue','genres','director','primary_actor']
  
# converting data frame to csv
file.to_csv("/Users/ajennings/Desktop/rutgers_bootcamp/Class_Project3/data_cleaning/movies_final_final.csv", header=headerList, index=False)
  
# display modified csv file
file2 = pd.read_csv("/Users/ajennings/Desktop/rutgers_bootcamp/Class_Project3/data_cleaning/movies_final_final.csv")
file2
# Out:
#       index                       original_title  production_budget  \
# 0        15                              Tangled          260000000
# 1        37                       Men in Black 3          215000000
# 2       759                               Sphere           73000000
# 3       186                         Transformers          151000000
# 4        38  Transformers: Revenge of the Fallen          210000000
# ...     ...                                  ...                ...
# 3210    124                        Suicide Squad          175000000
# 3211    134                           Waterworld          175000000
# 3212     28                         The Avengers          225000000
# 3213     28                         The Avengers          225000000
# 3214   6274                               Primer               7000
#
#       worldwide_gross    imdb_id       budget      revenue           genres  \
# ...
