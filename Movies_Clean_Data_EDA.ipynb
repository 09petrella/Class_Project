# %% [markdown]
# Movies_Clean Data File - Exploratory Data Analysis (EDA)
#
# Performing EDA will will help give insight to the data, an understanding of the data types, and allow us to determine what features are important and the relationships between them.  We can also test any underlying assumptions during the exploratory phase.

# %%
# Import the neccessary 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
#Load the data in to a dataframe and review the data
movies_df = pd.read_csv('./Resources/movies_clean.csv', encoding = "ISO-8859-1")
movies_df.head()
# Out:
#    ï»¿Index                               original_title  production_budget  \
# 0         1  Pirates of the Caribbean: On Stranger Tides          379000000
# 1         2                      Avengers: Age of Ultron          365000000
# 2         6                               Justice League          300000000
# 3        11                                  John Carter          263700000
# 4        12           Batman v Superman: Dawn of Justice          263000000
#
#    worldwide_gross    imbd_id       budget       revenue     genres  \
# 0       1045713802  tt1298650  380000000.0  1.045714e+09  Adventure
# 1       1395316979  tt2395427  280000000.0  1.405404e+09     Action
# 2        655945209  tt0974015  300000000.0  6.579000e+08     Action
# 3        282778100  tt0401729  260000000.0  2.841391e+08     Action
# 4        872395091  tt2975590  250000000.0  8.732602e+08     Action
#
#            producers        director           starring
# 0  Jerry Bruckheimer    Rob Marshall        Johnny Depp
# 1        Kevin Feige     Joss Whedon  Robert Downey Jr.
# 2      Charles Roven  Deborah Snyder           Jon Berg
# 3         Jim Morris    Colin Wilson    Lindsey Collins
# 4      Charles Roven  Deborah Snyder        Zack Snyder

# %%
# Dropped Index Column
#movies_df.drop(['ï»¿Index'], axis = 1)
movies_df.drop(movies_df.columns[0], axis = 1, inplace = True)

# %%
movies_df.describe(include='all')
# Out:
#        original_title  production_budget  worldwide_gross    imbd_id  \
# count            2983       2.983000e+03     2.983000e+03       2983
# unique           2983                NaN              NaN       2983
# top          Cop Land                NaN              NaN  tt1210166
# freq                1                NaN              NaN          1
# mean              NaN       4.301461e+07     1.211710e+08        NaN
# std               NaN       4.498188e+07     1.943322e+08        NaN
# min               NaN       9.000000e+03     0.000000e+00        NaN
# 25%               NaN       1.300000e+07     1.635524e+07        NaN
# 50%               NaN       2.900000e+07     5.264995e+07        NaN
# 75%               NaN       5.900000e+07     1.435176e+08        NaN
# max               NaN       3.790000e+08     2.845900e+09        NaN
#
#               budget       revenue  genres     producers       director  \
# count   2.942000e+03  2.946000e+03    2982          2975           2982
# unique           NaN           NaN      18          1403           1822
# top              NaN           NaN  Comedy  Brian Grazer  Gary Lucchesi
# freq             NaN           NaN     718            27             13
# mean    4.355535e+07  1.188980e+08     NaN           NaN            NaN
# std     4.457893e+07  1.894694e+08     NaN           NaN            NaN
# min     1.000000e+00  8.000000e+00     NaN           NaN            NaN
# 25%     1.300000e+07  1.573590e+07     NaN           NaN            NaN
# 50%     3.000000e+07  5.126604e+07     NaN           NaN            NaN
# 75%     6.000000e+07  1.401518e+08     NaN           NaN            NaN
# max     3.800000e+08  2.787965e+09     NaN           NaN            NaN
#
#            starring
# count          2982
# unique         1992
# top     Stacey Sher
# freq             11
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %%
# Shows the numbers of rows and columns

movies_df.shape
# Out:
# (2983, 10)

# %%
#Check to see if the dtypes line up to  ake sure the fields with numbers are a numeric data type and text fields are objects 

movies_df.info()

# there are null values in some of these fields and we will need to address them by deciding to drop, fill or ignore them
# Key fields such are the gross, budget, actor/actress, and director will need to get dropped or filled
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2983 entries, 0 to 2982
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_title     2983 non-null   object
#  1   production_budget  2983 non-null   int64
#  2   worldwide_gross    2983 non-null   int64
#  3   imbd_id            2983 non-null   object
#  4   budget             2942 non-null   float64
#  5   revenue            2946 non-null   float64
#  6   genres             2982 non-null   object
#  7   producers          2975 non-null   object
#  8   director           2982 non-null   object
#  9   starring           2982 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 233.2+ KB

# %%
# Check for the number of Nulls/Nans
movies_df.isnull().sum()
# Out:
# original_title        0
# production_budget     0
# worldwide_gross       0
# imbd_id               0
# budget               41
# revenue              37
# genres                1
# producers             8
# director              1
# starring              1
# dtype: int64

# %%
# Visualizing Missing Values
sn.heatmap(movies_df.isnull(), cbar=False, yticklabels=False, cmap='plasma')

#Budget and Revenue has some missing values
# Out:
# <AxesSubplot:>

# %%
At this point we can see that there are 2983 Movies and 10 columns in our dataset
The data types consist of float64(2), int64(2), and objects object(6)
There are some null values in the budget and revenue fields
This is important because we are expecting the budget field to be a significant influencer of the Gross Revenue
# Out:
#   File "<ipython-input-46-f82d692ba001>", line 1
#     At this point we can see that there are 2983 Movies and 10 columns in our dataset
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ###### How do we want to handle nulls in our budget and gross colums? Drop them? Fill them in from other data sources?  Fill budget in with a mean?

# %%
# Another item to look for in key numeric fields is 0 values

print(movies_df.budget[movies_df.budget==0].count())
print(movies_df.revenue[movies_df.revenue==0].count())

# no zeros in budget or gross columns
# Out:
# 0
# 0

# %%
# Filter out rows with a zero to a different dataFrame --- if needed --- might use with NAN later on
# movies_df_0_budget = movies_df[movies_df.budget==0].reset_index(drop=True)

# movies_df = movies_df[movies_df.budget!=0].reset_index(drop=True)


# Check 0 budgets again
# movies_df.budget[df.budget==0].count()

# %% [markdown]
# ##### do something with release date??  Parse it out with the above code or drop it all together

# %%
# Total number of rows and columns
movies_df.shape

# Rows containing duplicate data
duplicate_rows_df = movies_df[movies_df.duplicated()]
print('number of duplicate rows: ', duplicate_rows_df.shape)

# No Duplicate Rows
# Out:
# number of duplicate rows:  (0, 10)

# %%
# Reviewing the unique values in categorical variables  

# ---- not my favorite view, might move this to column breakout analysis and show unique values there

# can scan for an outlier, but the analysis comes later

#print('Movie Name')
#print(*list(movies_df.original_title.unique()))  #to many print to be useful
print('Genre')
print(*list(movies_df.genres.unique()))
print('Revenue')
print(*list(movies_df.revenue.unique()))
print('Worldwide Gross')
print(*list(movies_df.worldwide_gross.unique()))
print('Budget')
print(*list(movies_df.budget.unique()))
print('Production Budget')
print(*list(movies_df.production_budget.unique()))
print('Main Actor/Actress')
print(*list(movies_df.starring.unique()))
print('Director')
print(*list(movies_df.director.unique()))
print('Producer')
print(*list(movies_df.producers.unique()))
#print('Runtime')
#print(*list(movies_df.runtime.unique()))

#Skipped Index and IMDBID
# Out:
# Genre
# Adventure Action Family Animation Science Fiction Thriller Drama Fantasy Horror Comedy War History Western Romance Crime Mystery Music Documentary nan
# Revenue
# 1045713802.0 1405403694.0 657900000.0 284139100.0 873260194.0 788241776.0 591794936.0 1153304495.0 933959197.0 958400000.0 1238764765.0 2787965087.0 391081192.0 1084939099.0 794191988.0 586090727.0 1519557910.0 662845518.0 419651413.0 89289910.0 752215857.0 303025485.0 604942143.0 1513528810.0 624026776.0 836297228.0 1091405097.0 459359555.0 310669540.0 550000000.0 372234864.0 1845034188.0 1056057273.0 1028570889.0 1066969703.0 1215439994.0 783766341.0 1025491110.0 743559607.0 747862775.0 705717432.0 559852396.0 769653595.0 371353001.0 219851172.0 304320254.0 1123746996.0 407778013.0 197687603.0 1506249360.0 467365246.0 531865000.0 351040419.0 407602906.0 331926147.0 585174222.0 1004558444.0 786636033.0 538983207.0 566652812.0 343471816.0 504050219.0 854000000.0 758539785.0 258022233.0 356743061.0 185770160.0 90024292.0 183987723.0 543934787.0 370541256.0 966550600.0 857611174.0 745600054.0 735099082.0 350170057.0 302469017.0 222104681.0 401128639.0 173000000.0 264218220.0 146175066.0 150962475.0 773328629.0 623933331.0 714766572.0 710644566.0 305875730.0 396600000.0 435000000.0 300257475.0 209154322.0 752600867.0 652105443.0 494878759.0 471222889.0 675120017.0 389681935.0 1262886337.0 798958165.0 825532764.0 653428261.0 529076069.0 353624124.0 333932083.0 215283742.0 181674817.0 433677183.0 121790373.0 167298192.0 369907963.0 449220945.0 709709780.0 820580447.0 1274219009.0 1023784195.0 938212738.0 895921036.0 738599701.0 643034466.0 624029371.0 474968763.0 623722818.0 644571402.0 374218673.0 519876949.0 449326618.0 603900354.0 373062864.0 413106170.0 665692281.0 378858340.0 424988211.0 314432665.0 397850012.0 356613439.0 497409852.0 318502923.0 287594577.0 292817841.0 309979994.0 301000000.0 195735876.0 245527149.0 205366737.0 139800000.0 331957105.0 38992758.0 64459316.0 746921274.0 609123048.0 448000000.0 272912430.0 306941670.0 119269486.0 229147509.0 385680446.0 553799566.0 370569774.0 521170825.0 285444603.0 371876278.0 456758981.0 268031828.0 183345589.0 150680864.0 821708551.0 185258983.0 76932943.0 163712074.0 245360480.0 85131830.0 585178928.0 532950503.0 245724603.0 212011111.0 282570682.0 245623848.0 150406466.0 163794509.0 591739379.0 373552094.0 847423452.0 789804554.0 442824138.0 631744560.0 519311965.0 368871007.0 321887208.0 273339556.0 500188435.0 293329073.0 362637473.0 371940071.0 243843127.0 61648500.0 354248063.0 616801808.0 349424282.0 752100229.0 767820459.0 626137675.0 477200000.0 334615000.0 544272402.0 498814908.0 232713139.0 403170142.0 276572938.0 238207122.0 198802074.0 64493915.0 61698899.0 345141403.0 325756637.0 415484914.0 609016565.0 228738393.0 259175788.0 286140700.0 286168572.0 142337240.0 169956806.0 242688965.0 115772733.0 nan 93945766.0 162949164.0 261930431.0 881779.0 562816256.0 415440673.0 77628265.0 237382724.0 574480841.0 470490832.0 563749323.0 383531464.0 362744280.0 215294342.0 337580051.0 102000000.0 2000000.0 227817248.0 299268508.0 177238796.0 347434178.0 103951461.0 164508066.0 211643158.0 169801921.0 72178895.0 87713825.0 630161890.0 347234916.0 267045765.0 408579038.0 10372291.0 457640427.0 214104620.0 599045960.0 358372926.0 130482868.0 876688482.0 336529144.0 362211740.0 347451894.0 425368238.0 310650585.0 378882411.0 266465037.0 242988466.0 170432927.0 392000694.0 268426634.0 242295562.0 100138851.0 169327687.0 312573423.0 100086793.0 249288105.0 243400000.0 278731369.0 211989043.0 170877916.0 140073390.0 121214377.0 68688831.0 121975011.0 82102379.0 206172544.0 109578115.0 94882889.0 133718711.0 93820758.0 103039258.0 59900000.0 7103973.0 246233113.0 433013274.0 193772504.0 232380243.0 543514353.0 877244782.0 172989651.0 288347692.0 226497209.0 104907746.0 167805466.0 263920180.0 76432727.0 93525586.0 94061311.0 114178613.0 940335536.0 1118888979.0 926287400.0 274703340.0 414351546.0 871368364.0 482860185.0 162839667.0 631442092.0 304654182.0 25819961.0 10017322.0 188133322.0 589390539.0 347325802.0 524028679.0 886686817.0 155464351.0 484635760.0 289847354.0 264105545 ...
# Worldwide Gross
# 1045713802 1395316979 655945209 282778100 872395091 1651023152 584899819 1151918521 929411069 959358436 1236703796 2845899541 391081192 1082228107 794861794 591692078 1515100211 667999518 417341288 260002115 757890267 313477717 602893340 1669979967 654213485 836519699 1104054072 459260946 322459006 550517357 367262558 2207986545 1055135598 1025006125 1068879522 1215392272 794697557 1025491110 743455810 747862775 708996336 560155383 757677748 365491792 219535492 69965374 1123794079 409953905 197687603 1514553486 467381584 531861650 353640419 411002906 333771037 585171547 998615789 786635413 554606532 561072059 335673708 1046649706 850482778 758536735 256585882 348902025 180047784 215098356 181982519 542537546 367028980 953554418 852830107 745744980 731463377 383541369 302469017 221229335 405760225 174131329 264246220 139630336 151716815 770882395 621156389 714401889 710644566 312719437 401021746 433058296 300150546 206627518 756244673 648415024 494870992 496511521 651023006 384169424 1270818066 807330936 728582465 648986787 529076069 355408305 329631958 217986320 181674817 438899824 122603824 167297191 489592267 449239853 708272592 818058221 1264377166 1004629935 939619849 886746240 738576929 634965560 624234272 475825484 626549695 644602516 358858124 518058826 449326618 599680774 374825760 402231063 664837547 367457874 427300260 310043823 399387745 490875846 483152040 319713881 287594577 292817841 328015029 305270083 195080579 238202668 205440387 142634358 334486852 39549758 179357126 746921271 614586270 448191819 269806430 306900902 121645390 229008658 386839614 554600000 370569776 521170825 285400000 375740705 456810575 268314513 199646680 138836756 821706375 186976250 76416746 265573859 245031679 85131830 573068425 532938302 245724600 212912137 286896578 245328374 157956466 164920076 606836535 366942531 864868047 789592708 444043396 631910531 518858449 385997896 321887208 273271982 492846291 290650494 352831065 373993951 251499665 79076678 356148063 614202315 353756621 766575131 767820459 630163454 485004754 535663443 555840117 527965936 493214888 402448265 280355920 238317814 211856088 61642798 61698899 345445403 328711434 416168316 619310368 229545589 227163273 286192091 287916633 142531552 166000000 242981799 107212751 167849187 93394462 163018913 258751370 856081053 560483719 416456852 77628265 232017848 579446407 456258539 563749323 382288147 362989076 215300000 330780051 208370892 302239672 229155503 263880341 177241171 348547523 76482461 150468000 218674938 167910690 72004159 87683966 653609107 348629585 270997378 402156682 10364769 456435588 212282709 594420283 358824714 130673154 875454054 336529144 362211740 331323410 449841566 310650574 365300000 267985456 236827677 170936470 389918903 262794441 234400000 325500000 169630573 311979256 99123656 249488115 243388614 278731369 212026975 96150482 171377916 139716717 121100000 69548641 95255485 82078046 209461378 91800000 97523020 126704591 89693309 103039258 59918422 7094995 250091610 435040395 183124621 238521247 542351353 879765137 159691085 294680778 223050874 104907746 165720921 263893838 65700000 94894448 91669648 108874967 936094852 1120214046 919148764 273330185 404561724 891216824 470986200 162839667 631441092 304249198 23911362 18517322 187861183 587790539 347425832 498438212 886686817 288693989 487519809 289660619 259736090 191145256 239373970 165900000 366101666 162122642 186049020 203932174 244041804 155750628 191200000 162753837 200859554 328325007 143049560 169400000 106000000 87420776 203653524 120100000 65716126 63356133 139877913 10551417 495700000 105021488 333132750 350100280 148715342 427230516 385000317 450728529 311001124 315268353 359347833 276014965 378223189 340384141 207884401 311744465 250649836 191932158 150422946 66941559 173613482 161510853 96971293 137298489 80831893 148168160 345033359 44650003 78353508 78948765 113487912 83080084 74120792 276294164 141507355 237685089 143985708 222640812 160388063 191558505 268268174 96024898 484468608 ...
# Budget
# 380000000.0 280000000.0 300000000.0 260000000.0 250000000.0 45000000.0 237000000.0 270000000.0 230000000.0 200000000.0 220000000.0 225000000.0 255000000.0 215000000.0 209000000.0 150000000.0 210000000.0 207000000.0 180000000.0 90000000.0 195000000.0 125000000.0 190000000.0 105000000.0 175000000.0 140000000.0 185000000.0 28000000.0 170000000.0 197471676.0 176000003.0 178000000.0 145000000.0 165000000.0 160000000.0 110000000.0 155000000.0 152000000.0 149000000.0 100000000.0 70000000.0 130000000.0 144000000.0 139000000.0 135000000.0 137000000.0 132000000.0 103000000.0 127500000.0 97000000.0 127000000.0 123000000.0 120000000.0 115000000.0 1500000.0 126000000.0 117000000.0 nan 112000000.0 116000000.0 25000000.0 107000000.0 108000000.0 80000000.0 102000000.0 84000000.0 99000000.0 98000000.0 95000000.0 92000000.0 65000000.0 94000000.0 79000000.0 81000000.0 93000000.0 75000000.0 88000000.0 68000000.0 87000000.0 85000000.0 60000000.0 82500000.0 82000000.0 78000000.0 76000000.0 73000000.0 50000000.0 58000000.0 53000000.0 55000000.0 52000000.0 74000000.0 9600000.0 72500000.0 72000000.0 71000000.0 66000000.0 69000000.0 36000000.0 67000000.0 63000000.0 43000000.0 64000000.0 62000000.0 44000000.0 61000000.0 10000000.0 78146652.0 30000000.0 35000000.0 83000000.0 57000000.0 56000000.0 54000000.0 18000000.0 47000000.0 46000000.0 40000000.0 51000000.0 50200000.0 48000000.0 42000000.0 27000000.0 32000000.0 49900000.0 51500000.0 22000000.0 49000000.0 38000000.0 64400000.0 1300000.0 70800000.0 44500000.0 41000000.0 34000000.0 63600000.0 33000000.0 8000000.0 39000000.0 17000000.0 37000000.0 29000000.0 31000000.0 20500000.0 32500000.0 31500000.0 30250000.0 34200000.0 26000000.0 19000000.0 21000000.0 21500000.0 12000000.0 20000000.0 27500000.0 15000000.0 25530000.0 25100000.0 21150000.0 13000000.0 25300000.0 24000000.0 14000000.0 41300000.0 23000000.0 23600000.0 12500000.0 2000000.0 9000000.0 8700000.0 19400000.0 27220000.0 19100000.0 18500000.0 16000000.0 16500000.0 19800000.0 17500000.0 17700000.0 6500000.0 15600000.0 15500000.0 7000000.0 14600000.0 11000000.0 13500000.0 6000000.0 5000000.0 1200000.0 11800000.0 11500000.0 10500000.0 3100000.0 15.0 10800000.0 10600000.0 8500000.0 12600000.0 4000000.0 3200000.0 9500000.0 86000000.0 7500000.0 10200000.0 10284523.0 7400000.0 7300000.0 7200000.0 6600000.0 700000.0 6900000.0 6800000.0 5250000.0 6400000.0 6.0 5500000.0 134005.0 5800000.0 4900000.0 3300000.0 4600000.0 3000000.0 10831173.0 1000000.0 4800000.0 4500000.0 3600000.0 3500000.0 4696772.0 3400000.0 2962051.0 2800000.0 2700000.0 2600000.0 2500000.0 2400000.0 2300000.0 2100000.0 3800000.0 1900000.0 1800000.0 500000.0 1700000.0 1650000.0 1400000.0 600000.0 1.0 900000.0 916000.0 855000.0 800000.0 750000.0 65000.0 60000.0 2053648.0 475000.0 225000.0 420000.0 400000.0 375000.0 300000.0 1750000.0 312000.0 250000.0 200000.0 100000.0 150000.0 135000.0 40000.0 70000.0 28000.0 27000.0 23000.0 9000.0
# Production Budget
# 379000000 365000000 300000000 263700000 263000000 260000000 250000000 237000000 232000000 230000000 225000000 220000000 217000000 215000000 210000000 207000000 205000000 200000000 195000000 190000000 187500000 186000000 185000000 182000000 180000000 179000000 178000000 175000000 170000000 165000000 160000000 156000000 155000000 152000000 151500000 151000000 150000000 149000000 145000000 144000000 140000000 139000000 138000000 137500000 137000000 135000000 132000000 130000000 127500000 127000000 125000000 123000000 120000000 117000000 116000000 115000000 112000000 110000000 109000000 108000000 105000000 103000000 102500000 102000000 100000000 99000000 98000000 97000000 95000000 94000000 93000000 92500000 92000000 91000000 90000000 88000000 87500000 87000000 86000000 85000000 84000000 82500000 82000000 81000000 80000000 79000000 78000000 76000000 75000000 74000000 73243106 73000000 72500000 72000000 71682975 71500000 70702619 70000000 69000000 68000000 67500000 67000000 66000000 65000000 64000000 63700000 63000000 62000000 61000000 60000000 58000000 57500000 57000000 56200000 56000000 55000000 54000000 53012938 53000000 52500000 52000000 51000000 50200000 50000000 49000000 48000000 47500000 47000000 46000000 45000000 44500000 44000000 43000000 42500000 42000000 41000000 40000000 39000000 38000000 37500000 37000000 36000000 35200000 35000000 34800000 34000000 33000000 32500000 32000000 31500000 31000000 30250000 30000000 29200000 29000000 28700000 28500000 28000000 27500000 27000000 26000000 25530000 25100000 25000000 24000000 23600000 23000000 22500000 22000000 21500000 21000000 20700000 20500000 20000000 19400000 19200000 19100000 19000000 18500000 18000000 17700000 17500000 17000000 16800000 16500000 16000000 15600000 15495600 15250000 15000000 14600000 14400000 14000000 13900000 13500000 13000000 12800000 12500000 12000000 11800000 11500000 11000000 10800000 10700000 10600000 10500000 10000000 9800000 9500000 9200000 9000000 8600000 8500000 8000000 7500000 7400000 7300000 7200000 7000000 6900000 6800000 6500000 6400000 6100000 6000000 5900000 5600000 5500000 5250000 5200000 5000000 4833610 4800000 4750000 4600000 4500000 4300000 4030000 4000000 3500000 3400000 3300000 3200000 3000000 2500000 2900000 2800000 2700000 2600000 2400000 2300000 2100000 2000000 1900000 1800000 1750000 1700000 1650000 1600000 1500000 1300000 1250000 1200000 1125000 1000000 916000 900000 825000 800000 775000 750000 700000 650000 600000 500000 450000 430000 420000 400000 375000 350000 340000 312000 300000 270000 250000 200000 175000 150000 135000 100000 70000 68000 66000 50000 27000 25000 23000 9000
# Main Actor/Actress
# Johnny Depp Robert Downey Jr. Jon Berg Lindsey Collins Zack Snyder Rob Minkoff Byron Howard Joe Russo David Yates Fran Walsh Michael Fottrell James Cameron Gilbert Adler Charles Roven Espen Sandberg Marc Forster Emma Thomas Philip Steuer Gore Verbinski Laura Ziskin Scott Stuber Don Murphy Colin Trevorrow Barry Sonnenfeld Avi Arad Russell Crowe Chris Weitz Simon Emanuel Ellen DeGeneres Tom Hanks Sam Raimi Suzanne Todd Billy Crystal Simon Kinberg Marc Webb Owen Wilson Larry J. Franco Victor Kubicek Martin Campbell Tony Bancroft Sean Daniel Bryan Singer Damon Lindelof Jeremy Kleiner Baz Luhrmann Jon Jashni Raymond Ochoa Jon Favreau Christopher Nolan Harrison Ford Brenda Chapman Lindsey Weber Ron Clements Chris Hemsworth Angelina Jolie Jonathan Glickman Alan Riche Martin Scorsese Dane DeHaan Lilly Wachowski Hutch Parker Jeffrey Silver Amy Poehler David Ayer Ed Asner Bob Ducsay Roger Birnbaum Charles Gordon Tory Tunnell Carl Rinsch Chris Pratt Rick Jaffa Gary Goetzman Rupert Sanders Mario F. Kassar Stephen Sommers Jeffrey Chernov Mike Mitchell Chris Williams Dean DeBlois John C. Reilly Lynda Obst Roland Emmerich Bill Condon Mike Myers Francis Lawrence Mary Parent Frank Marshall Nicolas Cage Mike Fleiss Thomas Tull Mark Wahlberg Iain Smith Michael Bay Jennifer Lee Rich Moore Daniel Radcliffe a John Musker Michael Mann Tim Burton Patton Oswalt Larry Franco Eric Darnell Hugh Jackman Michael Barnathan Jack Black PJ Voeten Zach Braff J. J. Abrams John Calley Colin Wilson Cameron Stevning Sam Rockwell Jonathan Liebesman Jack Rapke Harald Kloser Rick Yorn Steve Starkey Peter Lord Jay Baruchel Chris Buck Peter Ramsey Karen Baldwin Paul Feig Chris Evans Alessandro Carloni Richard Donner Jon M. Chu Tom Cruise Jenno Topping Sam Mercer Alex Proyas Deborah Snyder Kevin Feige Gale Anne Hurd Hironobu Sakaguchi Kirk DeMicco Alejandro G. IâÂ±âÂ°rritu John B. Carls Peter Weir Ryan Reynolds Brad Fuller Doug Mitchell Steven Spielberg 1 Mark Radcliffe Paul L. Sandberg Mark Osborne Paul Rudd Suzanne Buirgy Tom McGrath Martin Lawrence Carlos Saldanha Phillip Noyce Kathleen Kennedy Will Smith Mike Richardson Eric Leighton Lauren Shuler Donner Ron Howard Susan Downey Alec Baldwin Richard D. Zanuck Ridley Scott Jeffrey M. Weiner Arnold Schwarzenegger Len Wiseman Chris Wedge Ned Dowd Gail Katz David Womark Michael De Luca Nancy Juvonen Duncan Henderson Marty Bowen JosâÂ© Padilha David Twohy Alex Hyde-White The Wachowskis Walter Parkes Steve Pink Jim Gillespie John Goodman James Mangold Alison Rosenzweig Rob Letterman Dwayne Johnson Neil Patrick Harris Bruce Willis George Clooney Gary Levinsohn Graham King Anne Hathaway Seth Rogen Spike Seldin John Sanford Michael Peyser Orlando Bloom Michael Costigan Frank Coraci James Lassiter Michael Schaefer Topher Dow Ray Romano Fred Roos Branko Lustig Walter F. Parkes Lana Wachowski Joel Schumacher Jon Turteltaub Pilar Savone Jay Roach Christopher Miller Jimmy Miller Riza Aziz Chuck Russell Kirk Wise David Spade Kevin King Templeton Maurice Sendak Gil Netter Beau Flynn Peter Hyams Edgar J. Scherick Paula Weinstein Helen Mirren Paul Verhoeven Brad Silberling Patrick McCormick Pitof Danny Lerner Roy Conli Lloyd Levin John Baldecchi Will Ward Kate Cohen Lawrence Guterman Louis A. Stroller Cornelius Uliano Harvey Weinstein David Barron Steve Martino Darren Star Will Ferrell Mimi Rogers Don Paul Peter Jackson Lionel Wigram Albert Brooks Adam Bohling Ellen Goldsmith-Vein Craig T. Nelson John Moore John Lee Hancock Joel B. Michaels John Goldwyn Arthur M. Sarkissian Robert Zemeckis Ben Stiller Sââren StâÂ¶rmose John McTiernan Antoine Fuqua Chris Columbus Kevin Misher Thor Freudenthal Bobby Cohen Tony Scott William J. MacDonald Gary Sinise Clive Owen Sigurjââ¥n Sighvatsson Boaz Davidson Robert Kulzer William Horberg Brian Grazer Ralph Winter Gary Ross Wolfgang Petersen Vin Diesel Pouya Shahbazian Adam Sandler Kevin Lima Denzel Washington Roger Allers Kim Roth Glenn Close Brett Ratner Douglas Wick Jean-Jacques Anna ...
# Director
# Rob Marshall Joss Whedon Deborah Snyder Colin Wilson Roger Allers Nathan Greno Anthony Russo David Barron Zane Weiner Vin Diesel Jon Landau Jon Peters Christopher Nolan Joachim Râânning Barbara Broccoli Andrew Adamson Gore Verbinski Matt Tolmach Brian Goldner Tom DeSanto Patrick Crowley Laurie MacDonald Ralph Winter Brian Grazer Carolynne Cunningham Deborah Forte Allison Shearmur Andrew Stanton Lee Unkrich Shane Black Avi Arad Joe Roth Dan Scanlon Lauren Shuler Donner John Lasseter Mark Gordon Moritz Borman Greg Berlanti Barry Cook Chris Morgan David Dobkin Bryan Burk Dede Gardner Catherine Knapman Thomas Tull Peter Sohn Kevin Feige Charles Roven Steven Spielberg Mark Andrews Mary Parent Roberto Orci John Musker Taika Waititi Robert Stromberg Michael Poryes Timothy Headington Luc Besson Lana Wachowski Bryan Singer Tom Lassally Brigham Taylor Pete Docter Richard Suckle Brian Fee Barry Sonnenfeld Sean Daniel Gary Barber John Davis Joby Harold Eric McLeod James Gunn Jon Favreau Dylan Clark Robert Zemeckis Sam Mercer Bob Ducsay Brad Bird Teresa Cheng Don Hall Chris Sanders Rich Moore Harald Kloser Todd Lieberman Chris Miller Jon Kilik Jon Jashni Kathleen Kennedy Jon Turteltaub Duncan Henderson Alex Gartner Mark Vahradian Jerry Bruckheimer Chris Buck Byron Howard Mike Newell The Wachowskis Ron Clements James Lassiter Richard D. Zanuck Alan Taylor Emma Thomas Kenneth Branagh Mark Swift Chris Columbus Jennifer Yuh Nelson George Miller Mark Dindal Paula Wagner Ron Howard Diana Rathbun Christina Steinberg Hoyt H. Yeatman Jr. Chris Williams Polly Cohen Johnsen Steve Bing Graham King Bradley J. Fischer Benicio del Toro Jack Rapke David Sproxton Dean DeBlois Kevin Lima Denise Nolan Cascino Nancy Bernstein Howard Baldwin Amy Pascal Damon Lindelof Gale Anne Hurd Joe Johnston Joel Silver Edward Zwick Ridley Scott Frank Marshall Alex Proyas Ian Bryce Lloyd Levin Neal H. Moritz Larry J. Franco Jun Aida Jane Hartwell Steve Golin David Soren Andrew Form Bill Miller Pieter Jan Brugge Lara Breay John Stevenson Peyton Reed Chris Jenkins Michael Bay John C. Donkin Sunil Perkash Darren Aronofsky Peter Jackson Jada Pinkett Smith Ralph Zondag Simon Kinberg John Calley Lionel Wigram Tom McGrath Kevin De La Noy Walter Hill Joel Schumacher Toby Jaffe Denis L. Stewart Michael Crichton Wolfgang Petersen Matt Damon Ang Lee Steven Paul Leonard Goldberg Neill Blomkamp Brian Casentini Lucy Fisher Eric Newman Oley Sassone Grant Hill Todd Garner Karen Lauder Hutch Parker Tracie Graham-Rice Gregory Goodman Brad Peyton Raja Gosnell Len Wiseman Steven Soderbergh Mark Canton Sandy Climan Rodrigo Garcââ a Michel Gondry Susan Montford Tony Scott Will Finn Steve Perry Hal Lieberman Michael Mann Mike Thurmeier Andrew Karsch David Franzoni Kevin Misher Bonnie Curtis Stefan Arndt Peter MacGregor-Scott Tim Burton Reginald Hudlin Robert De Niro Stephanie Austin Phil Lord Will Ferrell Leonardo DiCaprio Jerry Davis Arnold Kopelson Gary Trousdale Danny Lerner Gary Goetzman Adam Goodman Barry Levine Bill Borden Donald De Line Zack Snyder Alan Marshall Jimmy Miller Douglas Wick Edward L. McDonnell Kevin King-Templeton Eric Fellner Broderick Johnson Scott Kroopf Michael Scott Bregman Bryan Schulz James Jacks Bob Weinstein Sarah Jessica Parker Adam McKay Bonne Radford Fran Walsh Joni Levin David Reid Larry Franco Wyck Godfrey Mark Johnson Laurence Mark  Jr. Jonathan Glickman Steve Starkey Brad Grey Ole Sâândberg Michael Tadross Todd Black 1 Don Hahn Michael Barnathan Marc Abraham Robert Evans Brian De Palma Antoine Fuqua Edward S. Feldman Avi Lerner Jeremy Bolt Mike Medavoy Penny Marshall Bernd Eichinger Martha De Laurentiis Jonathan Shestack Michael K. Ross Genndy Tartakovsky Daniel Espinosa Jill Culton Eddie Murphy Bernie Goldmann John D. Schofield Steve Roth Bill Corless Sarah Smith Martin Brest Nicholas Meyer Jorge Saralegui Charles Lippincott Arnold W. Messer David Foster Jack Giarraputo Gary Winick Lucas Foster Mike Richardson Peter Segal John Thompson Jim Carrey T ...
# Producer
# Jerry Bruckheimer Kevin Feige Charles Roven Jim Morris Don Hahn Roy Conli David Heyman Carolynne Cunningham Neal H. Moritz James Cameron Bryan Singer Emma Thomas Michael G. Wilson Mark Johnson Avi Arad Peter Berg Lorenzo di Bonaventura Frank Marshall Walter F. Parkes Lauren Shuler Donner Ridley Scott Jan Blenkin Bill Carraro Kathleen Kennedy Lindsey Collins Darla K. Anderson Laura Ziskin Richard D. Zanuck Kori Rae Denise Ream Harald Kloser Derek Anderson Donald De Line Pam Coats Alex Kurtzman J. J. Abrams Brad Pitt Lucy Fisher Guillermo del Toro Katherine Sarafian Thomas Tull Ron Clements Joe Roth Roger Birnbaum Jerry Weintraub Graham King Virginie Besson-Silla Grant Hill Simon Kinberg Erwin Stoff Jon Favreau Jonas Rivera Kevin Reher Jon Peters Stephen Sommers Tom Shadyac Kevin Costner Akiva Goldsman Pamela Abdy Peter Chernin Steve Starkey Hal Lieberman Damon Lindelof Gina Shay Bonnie Arnold Clark Spencer Dean Devlin David Hoberman Aron Warner Nina Jacobson CeâÂ°n Chaffin Wolfgang Petersen Thomas SchâÂºhly Michael Bay Peter Del Vecho Joel Silver Osnat Shurer Brad Grey Brad Lewis Mireille Soria Shawn Levy Melissa Cobb Doug Mitchell Randy Fullmer Tom Cruise Brian Grazer M. Night Shyamalan Jerry Seinfeld Basil Iwanyk Robert Zemeckis Roland Emmerich Scott Stuber Cecil Kramer Alex Schwartz Christina Steinberg Stephanie Austin Ivan Reitman Richard Donner Marshall Herskovitz Steven Spielberg Lawrence Gordon Mike Medavoy Chris Lee Kristine Belson Arnon Milchan Gore Verbinski Samuel Goldwyn Jr. Lisa Stewart George Miller Michael Mann Mark Swift Lara Breay Bruce Anderson Scott Franklin Caleeb Pinkett Peter M. Lenkov Pam Marsden Hutch Parker Ramsey Ann Naito David Giler Peter MacGregor-Scott Mary Parent John McTiernan Paula Weinstein Paul Greengrass Gil Netter Drew Barrymore Bill Block Haim Saban Douglas Wick Marc Abraham Scott Kroopf Steven Rabiner Cathy Konrad Scott Faye Terence Chang John Davis Beau Flynn Jordan Kerner Michael Fottrell Gianni Nunnari Joseph Drake Stephen J. Cannell Alice Dewey Goldstone Jan de Bont Bill Badalato Laurence Mark Lori Forte Simon Fields Gerald R. Molen Tim Burton Stacey Sher Jane Rosenthal Adam McKay Martin Scorsese Anne Kopelson Avi Lerner Tom Hanks Brett Ratner Armyan Bernstein Scott Rudin Zareh Nalbandian Jon Davison Sid & Marty Krofft Denise Di Novi Tim Bevan Andrew A. Kosove Erica Huggins Martin Bregman Craig Schulz Sean Daniel Alberto Grimaldi Michael Patrick King Karen Rosenfelt Jay Roach Julie Yorn Patrice Ledoux Brook Breton Graham Walters Barrie M. Osborne Matthew Vaughn Mark Canton John Walker Alex Young Ron Howard Renny Harlin Samuel Goldwyn Jack Rapke Stuart Cornfeld Christopher McQuarrie Adam Sandler Andrew Gunn David Brown Tom Jacobson Chris Columbus Andrew Z. Davis Kathryn Bigelow Fredrik Malmberg Paul W. S. Anderson Eric Esrailian Ian Bryce Dino De Laurentiis Bill Miller Gail Katz Michelle Murdocca Barry Josephson Edward S. Feldman Ryan Kavanaugh Jean-Jacques Annaud Steve Pegram Martin Brest Hawk Koch Edward R. Pressman Sean Bailey Jack Giarraputo Daniel Goldberg Dan Lin Janice Karman Leonard B. Stern Jerry Davis Nancy Meyers Gary Barber David Permut Sydney Pollack John Hughes Donna Roth Robert Simonds Todd Garner Paul Harris Boardman Jonathan Demme Nora Ephron James G. Robinson Stephen Deutsch Ted Hartley Clint Goldman Rob Marshall Bruce Berman Moshe Diamant Casey Silver Trevor Albert Chris Meledandri Hilary Shor Robert De Niro Bill Damaschke Marc Platt Don Simpson Craig Zadan Bobby Cohen Martin Campbell David Ellison Donna Cockrell F. Gary Gray Scott Aversano Sam Mercer Julie Ansell Ashok Amritraj Lawrence Bender Hunt Lowry Deborah Snyder Mark Gordon Lou Pitt Don Bluth Gale Anne Hurd Michael Barnathan Paul Tibbitt Andy Garcââ a Barry Mendel Jimmy Miller John Cohen Brian De Palma Barry Levinson James L. Brooks Judd Apatow Mel Gibson Frank Darabont Ted Field Charles Gordon Dan Halsted Antoine Fuqua Ori Marmur Bruce Davey George Clooney Rick Berman Tom Rosenberg Michael De Luca Lynd ...

# %%
## Review data types again now that we have seen the unique values and determine if any need to be changed? 

# Release date needs to be cleaned to be useful
# Year needs to be converted to Category so it isn't treated like a number

movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2983 entries, 0 to 2982
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_title     2983 non-null   object
#  1   production_budget  2983 non-null   int64
#  2   worldwide_gross    2983 non-null   int64
#  3   imbd_id            2983 non-null   object
#  4   budget             2942 non-null   float64
#  5   revenue            2946 non-null   float64
#  6   genres             2982 non-null   object
#  7   producers          2975 non-null   object
#  8   director           2982 non-null   object
#  9   starring           2982 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 233.2+ KB

# %%
# In looking at the unique values there was a movie with a run time of 366 minites whcih seems like an outlier
# Reviewing the row to get more information
# For now it will be left in --------------------------------------------------
# movies_df[movies_df.runtime==366.0]

#No Runtime in this dataset

# %%
## Years is showing as an integer and needs to be converted to a category
# movies_df.year=pd.Categorical(movies_df.year)
movies_df.Index=pd.Categorical(movies_df.index)
#no years in this dataset

# %% [markdown]
# #### Does anything else need to be converted to categorical?

# %%
# Check to see if changes took place
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2983 entries, 0 to 2982
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_title     2983 non-null   object
#  1   production_budget  2983 non-null   int64
#  2   worldwide_gross    2983 non-null   int64
#  3   imbd_id            2983 non-null   object
#  4   budget             2942 non-null   float64
#  5   revenue            2946 non-null   float64
#  6   genres             2982 non-null   object
#  7   producers          2975 non-null   object
#  8   director           2982 non-null   object
#  9   starring           2982 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 233.2+ KB

# %%
# Display only numeric cloumns
# The describe function provides the count, mean, standard deviation, minimum and maximum values and the quantities of 
# the data.
movies_df.describe().T
# Out:
#                     count          mean           std     min         25%  \
# production_budget  2983.0  4.301461e+07  4.498188e+07  9000.0  13000000.0
# worldwide_gross    2983.0  1.211710e+08  1.943322e+08     0.0  16355237.5
# budget             2942.0  4.355535e+07  4.457893e+07     1.0  13000000.0
# revenue            2946.0  1.188980e+08  1.894694e+08     8.0  15735902.0
#
#                           50%          75%           max
# production_budget  29000000.0   59000000.0  3.790000e+08
# worldwide_gross    52649951.0  143517634.0  2.845900e+09
# budget             30000000.0   60000000.0  3.800000e+08
# revenue            51266040.0  140151752.5  2.787965e+09

# %%
# Display all cloumns
movies_df.describe(include='all').T

# Look at the difference between 75% and Max for Budget
# Out:
#                     count unique            top freq              mean  \
# original_title       2983   2983       Cop Land    1               NaN
# production_budget  2983.0    NaN            NaN  NaN   43014605.044586
# worldwide_gross    2983.0    NaN            NaN  NaN  121171034.520617
# imbd_id              2983   2983      tt1210166    1               NaN
# budget             2942.0    NaN            NaN  NaN   43555348.580897
# revenue            2946.0    NaN            NaN  NaN  118897956.173795
# genres               2982     18         Comedy  718               NaN
# producers            2975   1403   Brian Grazer   27               NaN
# director             2982   1822  Gary Lucchesi   13               NaN
# starring             2982   1992    Stacey Sher   11               NaN
#
#                                 std     min         25%         50%  \
# original_title                  NaN     NaN         NaN         NaN
# production_budget   44981884.826417  9000.0  13000000.0  29000000.0
# worldwide_gross    194332184.887822     0.0  16355237.5  52649951.0
# imbd_id                         NaN     NaN         NaN         NaN
# budget              44578927.283908     1.0  13000000.0  30000000.0
# revenue            189469384.517833     8.0  15735902.0  51266040.0
# genres                          NaN     NaN         NaN         NaN
# producers                       NaN     NaN         NaN         NaN
# director                        NaN     NaN         NaN         NaN
# starring                        NaN     NaN         NaN         NaN
#
#                            75%           max
# original_title             NaN           NaN
# production_budget   59000000.0   379000000.0
# worldwide_gross    143517634.0  2845899541.0
# imbd_id                    NaN           NaN
# budget              60000000.0   380000000.0
# revenue            140151752.5  2787965087.0
# genres                     NaN           NaN
# producers                  NaN           NaN
# director                   NaN           NaN
# starring                   NaN           NaN

# %%
# Lets take a look at the movie with a 380m budget
movies_df[movies_df.budget==380000000.0]
# Out:
#                                 original_title  production_budget  \
# 0  Pirates of the Caribbean: On Stranger Tides          379000000
#
#    worldwide_gross    imbd_id       budget       revenue     genres  \
# 0       1045713802  tt1298650  380000000.0  1.045714e+09  Adventure
#
#            producers      director     starring
# 0  Jerry Bruckheimer  Rob Marshall  Johnny Depp

# %%
# Lets take a look at the movie with a production budget of 379m
movies_df[movies_df.production_budget==379000000.0]
# Out:
#                                 original_title  production_budget  \
# 0  Pirates of the Caribbean: On Stranger Tides          379000000
#
#    worldwide_gross    imbd_id       budget       revenue     genres  \
# 0       1045713802  tt1298650  380000000.0  1.045714e+09  Adventure
#
#            producers      director     starring
# 0  Jerry Bruckheimer  Rob Marshall  Johnny Depp

# %%
# Lets take a look at the movie with a 2 trillion in Worldwide gross revenue

movies_df[movies_df.worldwide_gross==2845899541.0]
# Out:
#    original_title  production_budget  worldwide_gross    imbd_id       budget  \
# 11         Avatar          237000000       2845899541  tt0499549  237000000.0
#
#          revenue  genres      producers    director       starring
# 11  2.787965e+09  Action  James Cameron  Jon Landau  James Cameron

# %%
# Lets take a look at the movie with a 2 trillion in gross revenue

movies_df[movies_df.revenue==2787965087.0]
# Out:
#    original_title  production_budget  worldwide_gross    imbd_id       budget  \
# 11         Avatar          237000000       2845899541  tt0499549  237000000.0
#
#          revenue  genres      producers    director       starring
# 11  2.787965e+09  Action  James Cameron  Jon Landau  James Cameron

# %%
# Display all cloumns
# movies_df.describe(include='all')

# %% [markdown]
# # Correlation Analysis

# %%
# HeatMaps: are a type of plot which is necessary to find the dependent variables. 
# One of the best ways to find the relationship between the features can be done using heat maps

corr=movies_df.corr(method='spearman')
plt.figure(figsize=(15,15))
sn.heatmap(corr,vmax=.8,linewidths=0.01,square=True,annot=True,cmap='YlGn',linecolor='black')

# Below, positive correlation is represented by dark shades and negative correlation by lighter shades.
# shows if one variable influenced by other variable

# Votes influences revenue the most with a positive correlation of .74
# Budget influences revenue the with a positive correlation of .69
# Out:
# <AxesSubplot:>

# %%
# Numerical Representation of the Correlations
corr = movies_df.corr()
corr
# Out:
#                    production_budget  worldwide_gross    budget   revenue
# production_budget           1.000000         0.725377  0.974683  0.722492
# worldwide_gross             0.725377         1.000000  0.702909  0.983616
# budget                      0.974683         0.702909  1.000000  0.712243
# revenue                     0.722492         0.983616  0.712243  1.000000

# %%
# plots between independent variable - production budget and target variable - gross
sn.regplot(x=movies_df.production_budget, y=movies_df.revenue, color='g')
# Out:
# <AxesSubplot:xlabel='production_budget', ylabel='revenue'>

# %%
# plots between independent variable - budget  and target variable - revenue
sn.regplot(x=movies_df.budget, y=movies_df.revenue, color='g')
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>

# %% [markdown]
# ### Need a comment here on the correlation analysis

# %%
## Analysis of numeric variables

## Function for finding outliers

def findoutliers(column):
    outliers=[]
    Q1=column.quantile(.25)
    Q3=column.quantile(.75)
    IQR=Q3-Q1
    lower_limit=Q1-(1.5*IQR)
    upper_limit=Q3+(1.5*IQR)
    for out1 in column:
        if out1>upper_limit or out1 <lower_limit:
            outliers.append(out1)
            
    return np.array(outliers)  

def plotchart(col):
    fix, (ax1,ax2) =plt.subplots(1,2,figsize=(7,5))
    sn.boxplot(col, orient='v',ax=ax1)
    ax1.set_ylabel=col.name
    ax1.set_title('Box plot of {}'.format(col.name))
    sn.distplot(col,ax=ax2) 
    ax2.set_title('Distribution plot of {}'.format(col.name))
    
def analysis_column(col):
    print('count of outliers ', len(findoutliers(col)))
    print('Mean ',format(col.mean()))
    print('Median ',format(col.median()))
    print('Missing values',format(col.isnull().sum()))
    print('% of Missing values',format(round(100*(col.isnull().sum()/len(col)),2)))
    
    plotchart(col)

# %% [markdown]
# Revenue Analysis

# %%
# Analysis on Revenue
# we know Q3 AND Q1 AND IQR=Q3-Q1, any data point which is less than Q1-1.5IQR or Q3+1.5IQR are consider as outlier
# There seem to be outliers at the upper end of the Gross Revenue

Q1=movies_df.revenue.quantile(.25)
Q3=movies_df.revenue.quantile(.75)
IQR=Q3-Q1
lower_limit=Q1-(1.5*IQR)
upper_limit=Q3+(1.5*IQR)
print("Min Value",movies_df.revenue.min())
print("Max Value ",movies_df.revenue.max())
print("Q1 ",Q1)
print("Q3 ",Q3)
print("IQR ",IQR)
print('lower_limit',lower_limit)
print('upper_limit',upper_limit)
# Out:
# Min Value 8.0
# Max Value  2787965087.0
# Q1  15735902.0
# Q3  140151752.5
# IQR  124415850.5
# lower_limit -170887873.75
# upper_limit 326775528.25

# %%
# Revenue Analysis and Individual metric to look for outliers and distribution of data
analysis_column(movies_df.revenue)
# Out:
# count of outliers  269
# Mean  118897956.17379497
# Median  51266040.0
# Missing values 37
# % of Missing values 1.24

# %%
# Gross Histogram — refers to the frequency of occurrence of variables in an interval.
movies_df.revenue.hist()
# Out:
# <AxesSubplot:>

# %%
# Revenue vs # of Movies
ax_revenue = sn.distplot(movies_df.revenue,kde=False)
ax_revenue.set_title('Revenue vs Number of Movies')
ax_revenue.set_xlabel('Revenue')
ax_revenue.set_ylabel('Number of Movies')
#plt.savefig("revenue_vs_number_of_movies.png")
# Out:
# Text(0, 0.5, 'Number of Movies')

# %% [markdown]
# Budget Analysis

# %%
# Analysis on Budget
# we know Q3 AND Q1 AND IQR=Q3-Q1, any data point which is less than Q1-1.5IQR or Q3+1.5IQR are consider as outlier
# There seem to be outliers at the upper end of the budget

Q1=movies_df.budget.quantile(.25)
Q3=movies_df.budget.quantile(.75)
IQR=Q3-Q1
lower_limit=Q1-(1.5*IQR)
upper_limit=Q3+(1.5*IQR)
print("Min Value",movies_df.budget.min())
print("Max Value ",movies_df.budget.max())
print("Q1 ",Q1)
print("Q3 ",Q3)
print("IQR ",IQR)
print('lower_limit',lower_limit)
print('upper_limit',upper_limit)
# Out:
# Min Value 1.0
# Max Value  380000000.0
# Q1  13000000.0
# Q3  60000000.0
# IQR  47000000.0
# lower_limit -57500000.0
# upper_limit 130500000.0

# %%
# Budget Analysis and Individual metric to look for outliers and distribution of data
analysis_column(movies_df.budget)
# Out:
# count of outliers  177
# Mean  43555348.580897346
# Median  30000000.0
# Missing values 41
# % of Missing values 1.37

# %%
movies_df.budget.hist()
# Histogram — refers to the frequency of occurrence of variables in an interval.
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Histogram  Visualizations

# %%
# Using Histograms to to check for outliers in numerical columns
bins = len(movies_df)
plt.figure(figsize=(15, 6))

plt.subplot(1, 3, 1)
plt.hist(movies_df.budget, bins=20)
plt.title('budget')

plt.subplot(1, 3, 2)
plt.hist(movies_df.revenue, bins=20)
plt.title('gross')


plt.show()

# %% [markdown]
# Most Movies had a budget below 100M Budgets, Revenue below 200M and a Runtime between 75 and 160 min
# Should movies with extreme outliers in one of these categories be dropped?
# Leaving in for now...

# %% [markdown]
# ## Categorical Analysis

# %%
movies_df.starring.value_counts()
# Out:
# Stacey Sher          11
# Tom Rosenberg        10
# 1                     9
# Scott Rudin           9
# Jonathan Glickman     9
#                      ..
# Michael Schiffer      1
# Harry J. Ufland       1
# Anjelica Huston       1
# Peter R  de vries     1
# Benjamin Waisbren     1
# Name: starring, Length: 1992, dtype: int64

# %%
# in percentage
movies_df.starring.value_counts(normalize=True)
# that Nicolas Cage is .56%
# Out:
# Stacey Sher          0.003689
# Tom Rosenberg        0.003353
# 1                    0.003018
# Scott Rudin          0.003018
# Jonathan Glickman    0.003018
#                        ...
# Michael Schiffer     0.000335
# Harry J. Ufland      0.000335
# Anjelica Huston      0.000335
# Peter R  de vries    0.000335
# Benjamin Waisbren    0.000335
# Name: starring, Length: 1992, dtype: float64

# %%
# Bar plot for Star Category  - #too many to see something usefull here
# sn.factorplot('starring',data=movies_df,kind='count')

# %%
movies_df.director.value_counts()
# Out:
# Gary Lucchesi         13
# Chris Columbus        12
# Michael Shamberg      12
# Jack Giarraputo       11
# Eric Fellner          10
#                       ..
# Bob Ducsay             1
# Charles Lippincott     1
# Matthew Cane           1
# Jet Li                 1
# Todd Solondz           1
# Name: director, Length: 1822, dtype: int64

# %%
# in percentage
movies_df.director.value_counts(normalize=True)
# Out:
# Gary Lucchesi         0.004359
# Chris Columbus        0.004024
# Michael Shamberg      0.004024
# Jack Giarraputo       0.003689
# Eric Fellner          0.003353
#                         ...
# Bob Ducsay            0.000335
# Charles Lippincott    0.000335
# Matthew Cane          0.000335
# Jet Li                0.000335
# Todd Solondz          0.000335
# Name: director, Length: 1822, dtype: float64

# %%
# Bar plot for Director Category  - #too many to see something usefull here
# sn.factorplot('director',data=movies_df,kind='count')

# %%
movies_df.producers.value_counts()
# Out:
# Brian Grazer      27
# Neal H. Moritz    26
# Joel Silver       26
# Scott Rudin       25
# John Davis        22
#                   ..
# Gregory Chou       1
# Hilary Henkin      1
# Chris Coen         1
# Lisa Stewart       1
# David Glasser      1
# Name: producers, Length: 1403, dtype: int64

# %% [markdown]
# #### for actors / directors  should we groups the low volumes together?

# %%
# in percentage
movies_df.producers.value_counts(normalize=True)
# Out:
# Brian Grazer      0.009076
# Neal H. Moritz    0.008739
# Joel Silver       0.008739
# Scott Rudin       0.008403
# John Davis        0.007395
#                     ...
# Gregory Chou      0.000336
# Hilary Henkin     0.000336
# Chris Coen        0.000336
# Lisa Stewart      0.000336
# David Glasser     0.000336
# Name: producers, Length: 1403, dtype: float64

# %%
movies_df["genres"].unique()
# Out:
# array(['Adventure', 'Action', 'Family', 'Animation', 'Science Fiction',
#        'Thriller', 'Drama', 'Fantasy', 'Horror', 'Comedy', 'War',
#        'History', 'Western', 'Romance', 'Crime', 'Mystery', 'Music',
#        'Documentary', nan], dtype=object)

# %%
plt.figure(figsize=(15,10))
sn.countplot(x = movies_df["genres"])
plt.show()

# %% [markdown]
# 18 unique Genre,
# Comedies having the larges number of movies in the dataset, followed by Action and then Drama
# These 3 make up more than 50% of all the movies in the dataset

# %% [markdown]
# # Data Relationships

# %%
# look at relationships between Categories and Revenue
movies_df_strings = movies_df.loc[:, ['director', 'genres', 'original_title', 'starring', 'producers']]
catgs = {}
for i in list(movies_df_strings.columns):
    catgs[i] = movies_df_strings[i].nunique()
    
catgs
# Out:
# {'director': 1822,
#  'genres': 18,
#  'original_title': 2983,
#  'starring': 1992,
#  'producers': 1403}

# %% [markdown]
# Some Categories have too many values to bar plot - director, name, star and producer

# %% [markdown]
# Animation has the highest average among the different Genre, followed by Family and Action.

# %%
# Genre of movies and Revenue - Box Plot
plt.figure(figsize=(16, 6))
sn.boxplot(x='genres', y='revenue', data=movies_df.sort_values('revenue', ascending=False))
plt.xlabel('Genre')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.title('Revenue vs. Genre of Movie')
# Out:
# Text(0.5, 1.0, 'Revenue vs. Genre of Movie')

# %%
# Scatter PLot - Revenue vs Budget

movies_df.plot.scatter(x='budget', y='revenue', figsize=(10, 5))
plt.xlabel('Budget ($100M)')
plt.ylabel('Revenue ($100M)')
plt.title('Budget vs. Revenue')
# Out:
# Text(0.5, 1.0, 'Budget vs. Revenue')

# %% [markdown]
# This shows a somewhat linear relationship between gross revenue and budget which is not suprise.
# One could assume the more you spend to make a movie the more revenue it might make.

# %%
# Distribution Histogram
movies_df.hist(bins=50,figsize=(17,17))
plt.show()

# %%
# Distibution - Density
movies_df.plot(kind='density', subplots=True, layout=(3,3), sharex=False, sharey=False,fontsize=10, figsize = (16, 16))
plt.show()

# %% [markdown]
# Most Variables seem to be right skewed or positive in relation to our target variable of Gross Revenue
# Score seems to be normally distributed

# %%
# Box Plot
movies_df.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False,fontsize=8, figsize = (15, 15))
plt.show()

# %%
# Scatter Matrix
sn.pairplot(movies_df,height=3) # scatter matrix
plt.show()

# %% [markdown]
# Looks to be outliers in all features.

# %%
# SCatter of just Gross vs Budget
plt.scatter(movies_df["revenue"],movies_df["budget"])
plt.xlabel("Gross Revenue")
plt.ylabel("Budget")
# Out:
# Text(0, 0.5, 'Budget')
