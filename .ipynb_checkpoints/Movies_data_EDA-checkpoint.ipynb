# %% [markdown]
# Exploratory Data Analysis (EDA) on the Movies Data
#
# Performing EDA will will help give insight to the data, an understanding of the data types, and allow us to determine what features are important and the relationships between them.  We can also test any underlying assumptions during the exploratory phase.

# %%
# Import the neccessary 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
#Load the data in to a dataframe and review the data
movies_df = pd.read_csv('./Resources/movies.csv', encoding = "ISO-8859-1")
movies_df.head()

#Data source: https://www.kaggle.com/datasets/danielgrijalvas/movies?select=movies.csv
#Contains movies from 1980 to early 2020
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
movies_df.describe(include='all')
# Out:
#           name rating   genre         year                      released  \
# count     7668   7591    7668  7668.000000                          7666
# unique    7512     12      19          NaN                          3414
# top     Hamlet      R  Comedy          NaN  May 17, 2019 (United States)
# freq         3   3697    2245          NaN                             9
# mean       NaN    NaN     NaN  2000.405451                           NaN
# std        NaN    NaN     NaN    11.153508                           NaN
# min        NaN    NaN     NaN  1980.000000                           NaN
# 25%        NaN    NaN     NaN  1991.000000                           NaN
# 50%        NaN    NaN     NaN  2000.000000                           NaN
# 75%        NaN    NaN     NaN  2010.000000                           NaN
# max        NaN    NaN     NaN  2020.000000                           NaN
#
#               score         votes     director       writer          star  \
# count   7665.000000  7.665000e+03         7668         7665          7667
# unique          NaN           NaN         2949         4535          2814
# top             NaN           NaN  Woody Allen  Woody Allen  Nicolas Cage
# freq            NaN           NaN           38           37            43
# mean       6.390411  8.810850e+04          NaN          NaN           NaN
# std        0.968842  1.633238e+05          NaN          NaN           NaN
# min        1.900000  7.000000e+00          NaN          NaN           NaN
# 25%        5.800000  9.100000e+03          NaN          NaN           NaN
# 50%        6.500000  3.300000e+04          NaN          NaN           NaN
# 75%        7.100000  9.300000e+04          NaN          NaN           NaN
# max        9.300000  2.400000e+06          NaN          NaN           NaN
#
#               country        budget         gross             company  \
# count            7665  5.497000e+03  7.479000e+03                7651
# unique             59           NaN           NaN                2385
# top     United States           NaN           NaN  Universal Pictures
# freq             5475           NaN           NaN                 377
# mean              NaN  3.558988e+07  7.850054e+07                 NaN
# std               NaN  4.145730e+07  1.657251e+08                 NaN
# min               NaN  3.000000e+03  3.090000e+02                 NaN
# 25%               NaN  1.000000e+07  4.532056e+06                 NaN
# 50%               NaN  2.050000e+07  2.020576e+07                 NaN
# 75%               NaN  4.500000e+07  7.601669e+07                 NaN
# max               NaN  3.560000e+08  2.847246e+09                 NaN
#
#             runtime
# count   7664.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean     107.261613
# std       18.581247
# min       55.000000
# 25%       95.000000
# 50%      104.000000
# 75%      116.000000
# max      366.000000

# %%
# Shows the numbers of rows and columns

movies_df.shape
# Out:
# (7668, 15)

# %%
#Check to see if the dtypes line up to  ake sure the fields with numbers are a numeric data type and text fields are objects 

movies_df.info()

# there are null values in some of these fields and we will need to address them by deciding to drop, fill or ignore them
# Key fields such are the gross, budget, actor/actress, and director will need to get dropped or filled
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
# Check for the number of Nulls/Nans
movies_df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
# Visualizing Missing Values
sn.heatmap(movies_df.isnull(), cbar=False, yticklabels=False, cmap='plasma')

#Budgets has numerous missing budgets
# Out:
# <AxesSubplot:>

# %% [markdown]
# At this point we can see that there are 7668 Movies and 15 columns in our dataset
# The data types consist of float64(5), int64(1), and objects object(9)
# There are a large number of null values in budget and gross fields
# This is important because we are expecting the budget field to be a significant influencer of the Gross Revenue

# %% [markdown]
# ###### How do we want to handle nulls in our budget and gross colums? Drop them? Fill them in from other data sources?  Fill budget in with a mean?

# %%
# Another item to look for in key numeric fields is 0 values

print(movies_df.budget[movies_df.budget==0].count())
print(movies_df.gross[movies_df.gross==0].count())

# no zeros in budget or gross columns
# Out:
# 0
# 0

# %%
# Filter out rows with a zero to a different dataFrame --- if needed --- might use with NAN later on
# movies_df_0_budget = movies_df[movies_df.budget==0].reset_index(drop=True)

# movies_df = movies_df[movies_df.budget!=0].reset_index(drop=True)


# Check 0 budgets again
# movies_df.budget[df.budget==0].count()

# %% [markdown]
# ##### do something with release date??  Parse it out with the above code or drop it all together

# %%
# Total number of rows and columns
movies_df.shape

# Rows containing duplicate data
duplicate_rows_df = movies_df[movies_df.duplicated()]
print('number of duplicate rows: ', duplicate_rows_df.shape)

# No Duplicate Rows
# Out:
# number of duplicate rows:  (0, 15)

# %%
# Reviewing the unique values in categorical variables  

# ---- not my favorite view, might move this to column breakout analysis and show unique values there

# can scan for an outlier, but the analysis comes later

#print('Movie Name')
#print(*list(movies_df.name.unique()))  #to many print to be useful
print('Rating')
print(*list(movies_df.rating.unique()))
print('Genre')
print(*list(movies_df.genre.unique()))
print('Year Released')
print(*list(movies_df.year.unique()))
#print('Released')
#print(*list(movies_df.released.unique()))  #to many print to be useful
print('Score')
print(*list(movies_df.score.unique()))
print('Votes')
print(*list(movies_df.votes.unique()))
print('Director')
print(*list(movies_df.director.unique()))
print('Writer')
print(*list(movies_df.writer.unique()))
print('Main Actor/Actress')
print(*list(movies_df.star.unique()))
print('Country')
print(*list(movies_df.country.unique()))
print('Budget')
print(*list(movies_df.budget.unique()))
print('Gross')
print(*list(movies_df.gross.unique()))
print('Production Company')
print(*list(movies_df.company.unique()))
print('Runtime')
print(*list(movies_df.runtime.unique()))
# Out:
# Rating
# R PG G nan Not Rated NC-17 Approved TV-PG PG-13 Unrated X TV-MA TV-14
# Genre
# Drama Adventure Action Comedy Horror Biography Crime Fantasy Family Sci-Fi Animation Romance Music Western Thriller History Mystery Sport Musical
# Year Released
# 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020
# Score
# 8.4 5.8 8.7 7.7 7.3 6.4 7.9 8.2 6.8 7.0 6.1 5.3 7.1 7.2 6.6 6.9 6.5 6.7 5.0 6.2 5.4 6.3 6.0 5.9 7.5 4.8 4.6 5.1 8.3 4.2 5.5 8.1 4.7 5.2 7.4 4.0 4.3 7.6 4.9 3.4 7.8 5.6 2.7 2.9 4.4 8.0 5.7 3.7 3.6 3.9 3.5 3.8 4.1 3.0 4.5 8.5 3.2 2.6 2.2 3.1 8.6 8.9 9.3 8.8 3.3 2.5 2.3 2.1 1.9 2.4 2.8 9.0 nan
# Votes
# 927000.0 65000.0 1200000.0 221000.0 108000.0 123000.0 188000.0 330000.0 101000.0 10000.0 18000.0 54000.0 30000.0 49000.0 37000.0 27000.0 21000.0 29000.0 66000.0 26000.0 20000.0 14000.0 22000.0 12000.0 33000.0 5100.0 4100.0 17000.0 8900.0 16000.0 15000.0 604.0 9100.0 24000.0 4300.0 11000.0 4000.0 5700.0 13000.0 9000.0 2000.0 3900.0 3100.0 4500.0 3700.0 6700.0 2900.0 2600.0 2400.0 5200.0 5300.0 1900.0 875.0 1400.0 2800.0 915.0 1500.0 1800.0 965.0 1100.0 585.0 1300.0 415.0 1000.0 546.0 643.0 351.0 4800.0 2100.0 269.0 740.0 599.0 211.0 593.0 230.0 905000.0 32000.0 97000.0 131000.0 192000.0 40000.0 47000.0 42000.0 59000.0 170000.0 237000.0 68000.0 34000.0 7600.0 60000.0 4200.0 61000.0 51000.0 94000.0 77000.0 87000.0 56000.0 19000.0 7300.0 3400.0 38000.0 28000.0 7900.0 7500.0 4900.0 7100.0 5600.0 9900.0 9400.0 4400.0 5800.0 891.0 3600.0 1600.0 829.0 761.0 2700.0 659.0 1700.0 928.0 920.0 384.0 674.0 1200.0 782.0 101.0 499.0 228.0 98000.0 710000.0 382000.0 141000.0 381000.0 234000.0 52000.0 41000.0 148000.0 73000.0 115000.0 2500.0 8100.0 44000.0 220000.0 100000.0 179000.0 8200.0 78000.0 45000.0 63000.0 9300.0 6500.0 25000.0 50000.0 7800.0 3500.0 2200.0 3000.0 2300.0 9800.0 6100.0 684.0 3800.0 501.0 768.0 818.0 683.0 914.0 322.0 984.0 538.0 785.0 838.0 653.0 895.0 460.0 665.0 352.0 256.0 253.0 651.0 240.0 75.0 336.0 766000.0 973000.0 83000.0 75000.0 93000.0 57000.0 31000.0 86000.0 134000.0 8700.0 3300.0 6900.0 3200.0 4600.0 8600.0 9700.0 6000.0 7200.0 5400.0 5500.0 4700.0 458.0 7400.0 938.0 701.0 208.0 115.0 747.0 786.0 456.0 617.0 513.0 681.0 368.0 661.0 360.0 235.0 300.0 826.0 169.0 131.0 182.0 275.0 51.0 313.0 79.0 812000.0 132000.0 365000.0 205000.0 321000.0 118000.0 459000.0 212000.0 377000.0 171000.0 53000.0 135000.0 204000.0 96000.0 62000.0 39000.0 71000.0 91000.0 46000.0 36000.0 157000.0 76000.0 35000.0 6600.0 8000.0 7700.0 8400.0 7000.0 983.0 5000.0 705.0 619.0 6800.0 816.0 856.0 446.0 866.0 807.0 634.0 440.0 822.0 794.0 212.0 733.0 586.0 952.0 262.0 241.0 270.0 424.0 94.0 184.0 67.0 216.0 73.0 172.0 105.0 252000.0 1100000.0 88000.0 367000.0 159000.0 191000.0 55000.0 48000.0 150000.0 89000.0 81000.0 117000.0 129000.0 9200.0 5900.0 23000.0 9600.0 8800.0 993.0 404.0 610.0 511.0 243.0 953.0 386.0 434.0 804.0 487.0 934.0 301.0 861.0 468.0 760.0 122.0 726.0 128.0 134.0 545.0 214.0 155.0 207.0 192.0 339.0 91.0 100.0 397.0 166.0 139.0 306000.0 668000.0 374000.0 127000.0 128000.0 389000.0 186000.0 165000.0 82000.0 58000.0 104000.0 69000.0 780.0 70000.0 43000.0 9500.0 6200.0 6300.0 976.0 790.0 565.0 454.0 906.0 783.0 616.0 879.0 543.0 258.0 503.0 153.0 937.0 377.0 735.0 367.0 533.0 592.0 840.0 453.0 525.0 754.0 922.0 437.0 675.0 402000.0 691000.0 240000.0 211000.0 289000.0 176000.0 130000.0 243000.0 79000.0 119000.0 144000.0 147000.0 111000.0 152000.0 67000.0 6400.0 999.0 882.0 997.0 512.0 905.0 872.0 878.0 541.0 771.0 834.0 862.0 697.0 390.0 639.0 810000.0 270000.0 483000.0 103000.0 92000.0 196000.0 187000.0 239000.0 158000.0 304000.0 125000.0 90000.0 8300.0 8500.0 497.0 994.0 688.0 309.0 998.0 613.0 949.0 707000.0 346000.0 442000.0 244000.0 167000.0 494000.0 146000.0 201000.0 64000.0 126000.0 166000.0 164000.0 85000.0 102000.0 703.0 677.0 716.0 881.0 490.0 917.0 201.0 849.0 274.0 943.0 666.0 710.0 877.0 696.0 776.0 694.0 353.0 370000.0 310000.0 299000.0 501000.0 203000.0 247000.0 344000.0 140000.0 456000.0 151000.0 416000.0 95000.0 945.0 712.0 979.0 995.0 406.0 930.0 958.0 1000000.0 1300000.0 180000.0 142000.0 182000.0 424000.0 74000.0 72000.0 116000.0 796.0 815.0 943000.0 112000.0 156000.0 199000.0 385000.0 242000.0 124000.0 274000.0 280000.0 284000.0 80000.0 318000.0 106000.0 160000.0 874.0 745.0 950.0 876.0 894000.0 206000.0 275000.0 163000.0 177000.0 589000.0 229000.0 122000.0 84000.0 464.0 2400000.0 1900000.0 970000.0 357000.0 339000.0 361000.0 154000.0 222000.0 301000.0 214000.0 168000.0 596000.0 193000.0 1500000.0 978000.0 277000.0 480000.0 913000.0 175000.0 282000.0 105000.0 133000.0 759.0 543000.0 216000.0 295000.0 202000.0  ...
# Director
# Stanley Kubrick Randal Kleiser Irvin Kershner Jim Abrahams Harold Ramis Sean S. Cunningham John Landis Martin Scorsese Richard Lester Walter Hill Buddy Van Horn Jamie Uys Robert Altman Robert Redford Brian De Palma Jeannot Szwarc Alan Parker Colin Higgins John Carpenter Sidney Poitier William Friedkin Michael Cimino Don Taylor Robert Greenwald James Bridges Ken Russell Ron Maxwell Jerry Jameson Stuart Rosenberg Paul Schrader Tony Bill Paul Lynch Hal Needham Lamont Johnson Jay Sandrich Howard Zieff Floyd Mutrux Kevin Connor Richard Fleischer Michael Apted John Hough Bruce Beresford Richard Rush Art Linson Mike Newell Tommy Chong Michael Ritchie Ulli Lommel Clive Donner Moustapha Akkad Woody Allen Jonathan Demme Nancy Walker Clint Eastwood Federico Fellini Lang Elliott James Goldstone Joe Camp Eric Karson James L. Conway Vincent McEveety Joel Oliansky Claudia Weill Jerry Schatzberg Daniel Petrie Anne Bancroft Vladimir Menshov Piers Haggard Bill Persky Martin Davidson Gary Weis Bill Melendez Marty Feldman Alan Rudolph Sidney Lumet Charles Jarrott Walter Bernstein Paul Mazursky Franco Rosso Kieth Merrill John Huston Gordon Willis Jack Smight Paul Grimault Gilbert Cates Michael Pressman Ãdouard Molinaro Chuck Barris Mike Nichols Larry Peerce Buck Henry Wing-Cho Yip Steven Spielberg Lawrence Kasdan Sam Raimi Bob Clark Desmond Davis John Boorman George Miller Wolfgang Petersen Ivan Reitman Andrzej Zulawski Michael Mann Franco Zeffirelli Terry Gilliam Alan Alda Steve Miner David Cronenberg John Glen Rick Rosenthal Harold Becker Warren Beatty Mark Rydell Directors Hugh Hudson Sydney Pollack John Derek Steve Gordon Louis Malle Carl Gottlieb Gary Sherman Mel Brooks Joe Dante Matthew Robbins Ivan Passer Jean-Jacques Annaud Graham Baker Frank Perry Alan Myerson Bob Rafelson Milos Forman Wes Craven Peter Yates Peter Weir Peter Hyams Blake Edwards Lucio Fulci John Irvin George Mihalka Tobe Hooper Francis Ford Coppola Karel Reisz Jim Henson Ulu Grosbard Michael Crichton Bruce Malmuth Burt Reynolds John G. Avildsen Richard Marquand Michael Wadleigh Mickey Rose Oliver Stone Jean-Jacques Beineix Ken Wiederhorn Peter Medak Steve Rash Michael Schultz Joel Schumacher James Ivory Herb Freed Ken Shapiro Herbert Ross Ralph Bakshi William A. Fraker Franklin J. Schaffner Ken Hughes Steve Carver Luis Valdez George Cukor Billy Wilder Oz Scott Albert Brooks Allan Arkush Martin Ritt Gus Trikonis Jack Fisk John Badham Terence Young Jean-Claude Tramont Roger Spottiswoode Alan J. Pakula Glenn Jordan John Schlesinger David Steinberg Noel Nosseck Byron Quisenberry Steven Hilliard Stern E.W. Swackhamer Ferdinando Baldi Jacques Rivette Allan King Amy Heckerling Ridley Scott John Milius Ted Kotcheff Taylor Hackford Patricia Birch Nicholas Meyer Stuart Gillard Boaz Davidson Richard Attenborough Steven Lisberger Don Bluth Sylvester Stallone Don Coscarelli George A. Romero Ingmar Bergman Tommy Lee Wallace Juan Piquer SimÃ³n Robert J. Rosenthal George Roy Hill Barry Levinson Ron Howard Jules Bass Sidney J. Furie Ken Finkleman Richard Donner Mark Rosman Guy Hamilton Albert Pyun Michael Winner Michael Miller Robert Towne Carl Reiner Damiano Damiani Costa-Gavras Graeme Clifford David Schmoeller David S. Ward Tim Hunter Tom Kennedy Richard T. Heffron Garry Marshall Richard Benjamin Robert Benton Charles Band Arthur Hiller Philippe Mora Ian Sharp Roger Christian Tony Richardson Robert Mulligan Norman Jewison Hal Ashby Fred Schepisi Jean-Claude Lord Bruce Paltrow John Frankenheimer James Glickenhaus Richard Brooks Wim Wenders Jerry Belson James Fargo Richard Loncraine Caleb Deschanel Delbert Mann Thomas K. Avildsen James Beshears Don Siegel Daniel Vigne Elliott Hong Fred Zinnemann Jamaa Fanaka Eric Till James Burrows Joe Layton Lewis Teague Wolf Gremm Fumihiko Takayama Robert Taylor John Wintergate Peter Duffell Peter Markle Paul Cox Paul Brickman Joe Alves Robert Hiltzik Adrian Lyne Philip Kaufman Noel Black Martha Coolidge James L. Brooks Tony Scott Stan Dragoti Jim McBri ...
# Writer
# Stephen King Henry De Vere Stacpoole Leigh Brackett Jim Abrahams Brian Doyle-Murray Victor Miller Dan Aykroyd Jake LaMotta Jerry Siegel Bill Bryden Stanford Sherman Jamie Uys Jules Feiffer Judith Guest Brian De Palma Richard Matheson Christopher Gore Patricia Resnick John Carpenter Bruce Jay Friedman William Friedkin Michael Cimino Thomas Hunter Richard Christian Danus Aaron Latham Paddy Chayefsky Kimi Peck Adam Kennedy W.D. Richter Paul Schrader Alan Ormsby William Gray Hal Needham David Eyre Neil Simon Nancy Meyers Floyd Mutrux Robert Jaffe Samson Raphaelson Thomas Rickman Brian Clemens Jonathan Hardy Lawrence B. Marcus Hunter S. Thompson Allan Scott Tommy Chong Peter Benchley Ulli Lommel Mel Brooks David Butler Woody Allen Bo Goldman Bronte Woodard Dennis Hackin Federico Fellini Tim Conway Gordon Thomas Rod Browning Leigh Chapman Ken Pettus Don Tait Joel Oliansky Eleanor Bergstein GÃ¶sta Stevens Lewis John Carlino Anne Bancroft Valentin Chernykh Rudy Dochtermann Cyra McFadden AJ Carothers Guy Thomas Charles M. Schulz Marty Feldman Big Boy Medlin Jay Presson Allen Ernest K. Gann Damon Runyon Jean Gruault Franco Rosso Ray Goldrup Gary Sherman Barry Siegel Martin Donovan Hans Christian Andersen Josh Greenfeld David Shaber Jean Poiret Chuck Barris Anne Beatts Hollis Hodges Buck Henry Hsin-Yi Chang Lawrence Kasdan John Landis Sam Raimi Bob Clark Beverley Cross Thomas Malory Terry Hayes Wolfgang Petersen Len Blum Andrzej Zulawski Brock Yates Frank Hohimer Scott Spencer Michael Palin Alan Alda Ron Kurz David Cronenberg Richard Maibaum Darryl Ponicsan Warren Beatty Ernest Thompson Daniel P. Mannix Colin Welland Kurt Luedtke Tom Rowe Yabo Yablonsky Steve Gordon Wallace Shawn Rudy De Luca Jeff Millar Gary Brandner Hal Barwood Newton Thornburg GÃ©rard Brach David Seltzer Christina Crawford Dan Greenburg David Mamet E.L. Doctorow Glenn M. Benest Steve Tesich David Williamson Peter Hyams Michael Kane Blake Edwards Dardano Sacchetti Peter Straub Stephen A. Miller Lawrence J. Block Armyan Bernstein John Fowles Tom Patchett John Gregory Dunne Michael Crichton William Diehl Thomas Berger Margaret Kelly Ken Follett Whitley Strieber Mickey Rose Marc Brandel Daniel Odier Alan Scholefield Heywood Gould Hal Dresner Fred Bauer Stanley Shapiro Bob Bonney Jean Rhys Anne Marisse Ken Shapiro Dennis Potter Ronni Kern Ivan Goff John Byrum Ruth Avergon James Bruner Luis Valdez Gerald Ayres Francis Veber Lonne Elder III Albert Brooks John Hill Gary DeVore Barry Schneider William D. Wittliff Brian Clark Robin Moore J.D. Reed Howard Kohn Edward Clinton Charlie Peters David Barry Byron Quisenberry Mary Rodgers Robert Littell Barry Rosen Wolfe Lowenthal Bulle Ogier Olive Frederickson Cameron Crowe Hampton Fancher Bill Lancaster Robert E. Howard Melissa Mathison David Morrell Douglas Day Stewart Ken Finkleman Carol Sobieski Steven Spielberg Roger Spottiswoode Gene Roddenberry Stuart Gillard Boaz Davidson William Styron John Briley Don McGuire Steven Lisberger Robert C. O'Brien Paul D. Zimmerman Sylvester Stallone Don Coscarelli A.B. 'Banjo' Paterson Roger Waters DeWitt Bodeen Ingmar Bergman Martin Kitrosser Alex Lasker Tommy Lee Wallace David Odell Barry Reed Dick Randall Bruce Rubin Mike Marvin John Irving Barry Levinson Larry L. King Lowell Ganz Randal Kleiser Peter S. Beagle Frank De Felitta Mark Rosman Anthony Shaffer Tom Karnowski David Engelbach Joseph Fraley Bob Kachler Robert Towne Carl Reiner Costa-Gavras Eric Bergren David Schmoeller John Steinbeck Ira Levin S.E. Hinton Jason Williams Mickey Spillane Paul Mazursky Michael Elias Norman Steinberg Robert Benton Alan J. Adler Barry Sandler Clancy Carlile Tom Holland Ed Graczyk George Markstein Thomas Baum Deric Washburn Bruno Barreto Sandy Howard Valerie Curtin Al Schwartz Brian Taggert Robert De Laurentiis John Hughes Henry Rosenbaum Israel Horovitz Richard Maxwell James Glickenhaus Charles McCarry Fred Mustard Stewart Robert Kramer Monica Mcgowan Johnson Franklin Thompson David Wagoner John McGreevey  ...
# Main Actor/Actress
# Jack Nicholson Brooke Shields Mark Hamill Robert Hays Chevy Chase Betsy Palmer John Belushi Robert De Niro Gene Hackman David Carradine Clint Eastwood N!xau Robin Williams Donald Sutherland Michael Caine Christopher Reeve Eddie Barth Jane Fonda Adrienne Barbeau Gene Wilder Al Pacino Kris Kristofferson Kirk Douglas Olivia Newton-John John Travolta William Hurt Tatum O'Neal Jason Robards Robert Redford Richard Gere Chris Makepeace Leslie Nielsen Burt Reynolds Scott Glenn Goldie Hawn Tony Danza Rory Calhoun Laurence Olivier Sissy Spacek Bette Davis Edward Woodward Peter O'Toole Peter Boyle Charlton Heston Cheech Marin Suzanna Love Don Adams Anthony Quinn Woody Allen Paul Le Mat Ray Simpson Marcello Mastroianni Tim Conway Paul Newman Chuck Norris Darren McGavin Charles Martin Smith Richard Dreyfuss Jill Clayburgh Willie Nelson Ellen Burstyn Dom DeLuise Vera Alentova Peter Sellers Martin Mull John Ritter Dudley Moore Scott Beach Marty Feldman Meat Loaf Ali MacGraw Elliott Gould Walter Matthau Michael Ontkean David N. Haynes Trevor Howard Paul Michael Glaser Talia Shire Shirley MacLaine Jean Martin George Burns Frank Langella Michel Serrault Chuck Barris Gilda Radner Treat Williams Bob Newhart Ka-Yan Leung Harrison Ford David Naughton Kurt Russell Bruce Campbell Dan Monahan Nigel Terry Mel Gibson JÃ¼rgen Prochnow Bill Murray Isabelle Adjani James Caan Sean Connery Alan Alda Jennifer O'Neill Roger Moore Jamie Lee Curtis George C. Scott Warren Beatty Katharine Hepburn Mickey Rooney Ben Cross Bo Derek Andre Gregory Ringo Starr James Farentino Mel Brooks Dee Wallace Peter MacNicol Jeff Bridges Everett McGill Sam Neill Faye Dunaway Sylvia Kristel James Cagney Maren Jensen Keith Carradine Julie Andrews Catriona MacColl Craig Wasson Paul Kelman Elizabeth Berridge Frederic Forrest Meryl Streep Jim Henson Albert Finney Sylvester Stallone Nell Schofield Kristen Riter Wilhelmenia Fernandez Klaus Kinski Lauren Tewes George Hamilton George Segal Lily Tomlin Kristy McNichol Christopher George Steve Martin Mews Small Klinton Spilsbury Lesley-Anne Down Leonard Mann Daniel Valdez Jacqueline Bisset Jack Lemmon Richard Pryor Albert Brooks Andy Kaufman Sally Field Robert Duvall Marsha Mason David Rasche Harry Hamlin Pepper Martin John Savage Leif Garrett Tony Anthony Bulle Ogier Sean Penn Arnold Schwarzenegger Henry Thomas Michelle Pfeiffer Aileen Quinn JoBeth Williams Nick Nolte William Shatner Willie Aames Lawrence Monoson Ben Kingsley Dustin Hoffman Elizabeth Hartman Marc Singer Hal Holbrook Bob Geldof Nastassja Kinski Bertil Guve Dana Kimmell Tom Atkins Scott Baio Kenny Rogers Steve Guttenberg Henry Winkler Peter Gallagher Barbara Hershey Kate McNeil Peter Ustinov Lee Horsley Charles Bronson Barry Bostwick Mariel Hemingway James Olson Jessica Lange Morgan Fairchild Matt Dillon Ben Murphy Armand Assante John Cassavetes Michael McKean Roy Scheider Robert Glaudini Ronny Cox Cher Lewis Collins Kathryn Harrold Season Hubley Jon Voight Michael Ironside Tim Matheson Gerrit Graham Michael O'Keefe Ken Wahl Allen Garfield Mark Blankfield Michael Palin Raul Julia John Hurt Robert Urich Toni Attell Joan Collins Bette Midler GÃ©rard Depardieu Johnny Yune Leon Isaac Kennedy Ryan O'Neal Mel Blanc Luciano Pavarotti Teresa Stratas Tom Skerritt Rainer Werner Fassbinder Lorne Greene Amy Madigan John Wintergate Elizabeth Edmonds Bill Schoppert Wendy Hughes C. Thomas Howell Tom Cruise Eddie Murphy Tom Berenger Dennis Quaid Keith Gordon Felissa Rose Jennifer Beals Matthew Broderick Sam Shepard Ken Marshall David Knell Christopher Walken Phoebe Cates Nicolas Cage James Woods Dan Aykroyd Peter Billingsley Catherine Deneuve Michael Keaton Anthony Perkins Burt Lancaster Matt Lattanzi Barbra Streisand Randy Norton Graham Chapman John Cleese Oleg Yankovskiy Jackie Gleason Rick Hill Rodney Dangerfield David Bowie Peter Keleghan Cliff Gorman Mary Beth McDonough Linda Blair Peter Strauss Tom Selleck Kevin Kline Don Francks Lou Ferrigno Christopher Atkins Tony Roberts Jane Alexan ...
# Country
# United Kingdom United States South Africa West Germany Canada Australia Libya Italy Soviet Union France Hong Kong South Korea Sweden Spain Mexico Switzerland Netherlands New Zealand Philippines Israel Japan Hungary Brazil Yugoslavia Argentina Taiwan Ireland Denmark Germany Iran China Belgium Austria Portugal Vietnam Republic of Macedonia Russia Federal Republic of Yugoslavia Greece Czech Republic Norway India Jamaica Aruba Thailand Colombia Romania nan United Arab Emirates Indonesia Turkey Serbia Poland Kenya Finland Iceland Chile Panama Malta Lebanon
# Budget
# 19000000.0 4500000.0 18000000.0 3500000.0 6000000.0 550000.0 27000000.0 54000000.0 10000000.0 15000000.0 5000000.0 20000000.0 6500000.0 5100000.0 nan 1000000.0 11000000.0 44000000.0 12000000.0 36000000.0 9000000.0 4800000.0 4000000.0 3000000.0 22000000.0 300000.0 35000000.0 7000000.0 900000.0 5500000.0 350000.0 2500000.0 1250000.0 28000000.0 14000000.0 32000000.0 12500000.0 2800000.0 8500000.0 16000000.0 400000.0 26000000.0 8000000.0 17000000.0 8600000.0 800000.0 250000.0 1500000.0 3800000.0 2700000.0 13000000.0 46000000.0 24000000.0 2000000.0 10500000.0 7500000.0 13200000.0 50000000.0 10700000.0 11200000.0 21000000.0 2300000.0 425000.0 9500000.0 11300000.0 750000.0 850000.0 13400000.0 10000.0 435000.0 25000000.0 32500000.0 6200000.0 39000000.0 20500000.0 9700000.0 47000000.0 27500000.0 5952000.0 3300000.0 5600000.0 1200000.0 457000.0 4520000.0 14500000.0 14400000.0 700000.0 11800000.0 220000.0 10100000.0 100000.0 50000.0 3000.0 323562.0 6400000.0 40000000.0 30000000.0 1800000.0 8200000.0 2600000.0 58000000.0 90000.0 7200000.0 2550000.0 1065000.0 4600000.0 15100000.0 6300000.0 221000.0 17500000.0 24500000.0 6900000.0 11500000.0 17900000.0 31000000.0 7600000.0 2200000.0 3200000.0 2400000.0 2410000.0 18500000.0 8800000.0 37000000.0 1900000.0 13800000.0 4700000.0 111000.0 1100000.0 175000.0 8700000.0 3401376.0 600000.0 22700000.0 23000000.0 3600000.0 8300000.0 55000000.0 29000000.0 12800000.0 3520000.0 75000.0 5300000.0 5800000.0 19897678.0 70000000.0 3700000.0 63000000.0 46630000.0 210000.0 48000000.0 16400000.0 22500000.0 27800000.0 500000.0 10400000.0 33000000.0 11987578.0 34000000.0 65000000.0 13500000.0 60000000.0 42000000.0 23000.0 38000000.0 4200000.0 5200000.0 230000.0 21800000.0 6700000.0 102000000.0 16500000.0 43000000.0 6788000.0 1400000.0 17010000.0 49000000.0 41000000.0 80000000.0 11700000.0 45000000.0 7000.0 3330000.0 130000.0 15500000.0 22769.0 38000.0 57000000.0 85000000.0 14600000.0 11900000.0 999999.0 115000000.0 4400000.0 62000000.0 27000.0 75000000.0 7400000.0 7850000.0 65897768.0 200000.0 17080000.0 19200000.0 72000000.0 52000000.0 100000000.0 90000000.0 29000001.0 175000000.0 53000000.0 30250000.0 98000000.0 68000000.0 4997987.0 238000.0 40997769.0 150000.0 92000000.0 4100000.0 67000000.0 1300000.0 25530000.0 21500000.0 200000000.0 93000000.0 105000000.0 125000000.0 116000000.0 73000000.0 110000000.0 160000000.0 180000.0 25000.0 31190000.0 140000000.0 120000000.0 95000000.0 130000000.0 60000.0 6000.0 66000000.0 71500000.0 2900000.0 133000000.0 135000000.0 170000000.0 34200000.0 82000000.0 30000.0 64000000.0 29750000.0 5250000.0 51000000.0 450000.0 103000000.0 41300000.0 127500000.0 123000000.0 83000000.0 63600000.0 76000000.0 84000000.0 87000000.0 17700000.0 19800000.0 21150000.0 107000000.0 1700000.0 94000000.0 137000000.0 139000000.0 78000000.0 59000000.0 142000000.0 6428966.0 15600000.0 10600000.0 150000000.0 12600000.0 79000000.0 81000000.0 109000000.0 128000000.0 56000000.0 35200000.0 780000.0 155000000.0 165000000.0 56600000.0 19250000.0 70000.0 180000000.0 132000000.0 113000000.0 207000000.0 126000000.0 950000.0 88000000.0 475000.0 7900000.0 19300000.0 169000.0 9600000.0 6800000.0 14200000.0 33100000.0 72500000.0 225000000.0 270000000.0 210000000.0 82500000.0 17300000.0 149000000.0 19400000.0 86000000.0 16800000.0 61000000.0 258000000.0 300000000.0 10200000.0 15000.0 60795000.0 7300000.0 3750000.0 185000000.0 145000000.0 10800000.0 25100000.0 9800000.0 14700000.0 237000000.0 250000000.0 23600000.0 3900000.0 37500000.0 260000000.0 69000000.0 117000000.0 112000000.0 650000.0 195000000.0 163000000.0 49900000.0 50200000.0 19100000.0 135000.0 125000.0 10920000.0 220000000.0 44500000.0 230000000.0 209000000.0 40600000.0 270000.0 15700000.0 8900000.0 26350000.0 16600000.0 7395080.0 7980000.0 13300000.0 39200000.0 190000000.0 215000000.0 10900000.0 25500000.0 12700000.0 420000.0 38600000.0 178000000.0 1600000.0 58800000.0 127000000.0 108000000.0 245000000.0 50100000.0 176000000.0 74000000.0 16200000.0 1480000 ...
# Gross
# 46998772.0 58853106.0 538375067.0 83453539.0 39846344.0 39754601.0 115229890.0 23402427.0 108185706.0 15795189.0 70687344.0 30031783.0 49823037.0 54766923.0 31899000.0 9709597.0 21202829.0 103300686.0 21448782.0 101300000.0 19814523.0 3484523.0 16647800.0 22762571.0 46918287.0 19853892.0 34326249.0 nan 37121708.0 22743674.0 22482952.0 14796236.0 66132626.0 534816.0 43995918.0 69847348.0 10000000.0 6342668.0 27118000.0 67182787.0 5000000.0 7063886.0 6659377.0 8415112.0 41675194.0 15716828.0 14662035.0 10389003.0 4309490.0 24265659.0 12516.0 3763988.0 6216067.0 18971000.0 18000000.0 14287755.0 17815212.0 3910019.0 7653061.0 10697276.0 9870727.0 15934737.0 14155617.0 2013193.0 5215015.0 4226370.0 2086905.0 11000000.0 6321392.0 4400000.0 109749.0 59167.0 2128395.0 2806659.0 167451.0 14504277.0 804713.0 6950125.0 6621520.0 2261507.0 1175855.0 15198912.0 389925971.0 24058838.0 30669378.0 25244626.0 2956630.0 111289673.0 12000000.0 41092328.0 34971136.0 23668369.0 11487676.0 85297000.0 1113538.0 72179579.0 11492915.0 32492674.0 42368025.0 50427646.0 21722776.0 14225876.0 54813222.0 25533818.0 35856053.0 40382659.0 119285432.0 63456988.0 59303359.0 40716963.0 36565280.0 10853418.0 95461682.0 5073.0 15965924.0 31672907.0 17985893.0 14110013.0 1752634.0 20962615.0 20471382.0 19032261.0 26279000.0 12376625.0 14920781.0 8279042.0 6400000.0 5732587.0 17374595.0 14867086.0 123843.0 23371905.0 5672031.0 7886857.0 636796.0 26890068.0 31206251.0 12850276.0 19905359.0 37000000.0 35610100.0 29916207.0 237000.0 17583634.0 10626725.0 5165432.0 8124257.0 2447576.0 15578237.0 110014.0 5229643.0 29200000.0 1118634.0 18826490.0 9566593.0 20259961.0 14923752.0 12042.0 26154211.0 9171289.0 12617845.0 2022771.0 1169875.0 3256082.0 14492125.0 7258543.0 31261269.0 2863642.0 2154696.0 11809387.0 17569027.0 1976198.0 8206145.0 5200986.0 4454295.0 3702028.0 10851261.0 25524778.0 2004742.0 18838812.0 1791147.0 16000000.0 6892098.0 17110.0 1622898.0 27092880.0 41676878.0 19632053.0 68851475.0 792910554.0 125212904.0 129795554.0 15171476.0 57063861.0 77142388.0 78868508.0 78912963.0 5588800.0 5829781.0 30036000.0 52767889.0 177200000.0 33000525.0 14665733.0 2536242.0 125052686.0 14056528.0 21028755.0 20659423.0 22265763.0 7000000.0 6795771.0 36690067.0 46708276.0 14400000.0 41630431.0 53993738.0 2032311.0 16897768.0 20225989.0 29712172.0 14099953.0 69701637.0 10278575.0 21095638.0 4968000.0 28229046.0 6455330.0 13277558.0 27150534.0 47118057.0 10604986.0 6110670.0 39103425.0 16100000.0 10490791.0 5675599.0 5672311.0 18196170.0 12534817.0 14000000.0 11378339.0 5301539.0 19282134.0 7400000.0 1515578.0 5005245.0 30688860.0 20123620.0 5979947.0 2270.0 11897978.0 4484991.0 7742572.0 840958.0 2666873.0 9056073.0 1054328.0 6118683.0 15782759.0 9077269.0 13253583.0 36821203.0 9217530.0 946461.0 1736123.0 13258670.0 2370376.0 10054150.0 9823934.0 13111101.0 263635.0 2977706.0 6328816.0 3583513.0 6668025.0 3700.0 3792188.0 6660333.0 7241180.0 143369.0 8000000.0 1474249.0 21134374.0 2914328.0 2869638.0 3723036.0 16894678.0 23671186.0 42914.0 199078.0 3178542.0 8693512.0 6062898.0 36299720.0 78350.0 12408066.0 2279543.0 6968359.0 3783329.0 3355948.0 22440.0 5124391.0 777087.0 65884703.0 25697647.0 475106177.0 63541777.0 61399552.0 90404800.0 59950623.0 56399659.0 64892670.0 87987055.0 21017849.0 92921203.0 79567667.0 21192315.0 16916617.0 24071666.0 20766616.0 67893619.0 14049540.0 17343596.0 2494480.0 2120439.0 108423749.0 29450919.0 55432841.0 20653717.0 21156152.0 67642693.0 5988322.0 64783827.0 42313354.0 19910002.0 34725000.0 5899678.0 9190819.0 35615609.0 17233166.0 4218594.0 22587834.0 40218899.0 760883.0 4786789.0 4300000.0 14949697.0 55269.0 20307325.0 5678950.0 11919250.0 33759266.0 8400000.0 8443124.0 6472990.0 15856028.0 12232628.0 29309766.0 2306560.0 1246141.0 2082215.0 10219460.0 10353438.0 17488564.0 7175592.0 30503151.0 10375893.0 4319001.0 13000000.0 1402962.0 23646952.0 6149983.0 16478265.0 28445927.0 29600000.0 694497.0 30379.0 10676194.0 14648076.0 5563 ...
# 338440.0 30579406.0 9808124.0 18463793.0 26937355.0 6759057.0 51339567.0 2342211.0 390128.0 30893885.0 3175469.0 49529913.0 28972508.0 5457664.0 52132.0 32568427.0 43655418.0 37105289.0 1138322.0 321457747.0 385680446.0 2847246203.0 31556061.0 185382813.0 360366870.0 302469017.0 469310836.0 934454096.0 178866158.0 791217826.0 93621340.0 87812371.0 102392080.0 60800444.0 524028679.0 210888950.0 309208309.0 735099102.0 373062864.0 46474181.0 43474578.0 77912251.0 60262836.0 961203.0 836303693.0 166842739.0 711025481.0 7413863.0 91509154.0 267045765.0 371353001.0 124596837.0 9760107.0 91980359.0 214104620.0 325113.0 127944208.0 317375031.0 3559160.0 775385.0 136316880.0 183658498.0 18599102.0 676126.0 485930816.0 27639579.0 16691303.0 35079650.0 20648328.0 381509870.0 92158961.0 171844840.0 1790061.0 90842646.0 45995223.0 104414200.0 31198531.0 100140916.0 27206120.0 40828540.0 61808775.0 413106170.0 62357900.0 17164820.0 63649529.0 101344412.0 243006126.0 22955544.0 122426792.0 17203507.0 321682600.0 32406507.0 47719794.0 31430334.0 10848783.0 10234475.0 61601280.0 69095771.0 68777554.0 24964890.0 1808.0 36348784.0 55720772.0 12035862.0 28190603.0 150166126.0 219103655.0 39421467.0 186167139.0 13657649.0 39457342.0 7043835.0 51417188.0 26096852.0 47405566.0 886686817.0 34572541.0 60253843.0 41633384.0 100734718.0 129540522.0 108394089.0 106387141.0 48428063.0 29196409.0 27127620.0 17874044.0 95714875.0 115375850.0 122444772.0 282737.0 71585235.0 68234154.0 2404300.0 48858618.0 2425535.0 54004950.0 73830347.0 183348429.0 33334176.0 16443609.0 138805831.0 15821907.0 76514050.0 13085023.0 44420167.0 348327.0 40105542.0 96753696.0 6577779.0 1060941.0 67153225.0 102366815.0 77578320.0 20768906.0 10606422.0 296557.0 45719985.0 7787487.0 19319671.0 10629321.0 36020534.0 155545279.0 879422.0 443140005.0 17280326.0 386078.0 77211836.0 12014663.0 101215.0 754301.0 39886986.0 5805279.0 20458873.0 292817898.0 85280250.0 15779455.0 36088028.0 44276335.0 19651093.0 26973554.0 14374652.0 10371451.0 78176181.0 76025134.0 41771168.0 26676.0 105647102.0 3676533.0 90508336.0 325286646.0 5102705.0 7878856.0 50812934.0 2166797.0 18434328.0 1595417.0 439587.0 38332994.0 221805.0 17976667.0 4515258.0 13514.0 1803412.0 896919.0 15300885.0 4591629.0 39291383.0 57881056.0 12764201.0 2372.0 37472736.0 32482728.0 4091378.0 118492.0 9368242.0 101860.0 18853164.0 836836967.0 623933331.0 294805697.0 48917974.0 271457301.0 49779728.0 96188903.0 329398046.0 154026136.0 977043483.0 4324817.0 224920375.0 321669741.0 5060438.0 99557032.0 592462816.0 199006387.0 1278650.0 319713881.0 494879471.0 67876281.0 7099598.0 290745055.0 89520336.0 1025468216.0 543113985.0 102820008.0 252276927.0 278780441.0 698491347.0 226497209.0 493214993.0 157107755.0 15440333.0 261989769.0 83188165.0 60738797.0 274470394.0 170458922.0 400063852.0 105734416.0 12966357.0 1066970811.0 67448651.0 75026327.0 427374317.0 129190869.0 45491656.0 45636368.0 321885765.0 29397654.0 167805466.0 359126022.0 204594016.0 6890432.0 177238796.0 7209912.0 64780213.0 336365676.0 76196538.0 9918093.0 127233108.0 19439764.0 67918658.0 56032889.0 10903312.0 293503354.0 60040976.0 13796834.0 115695182.0 300228084.0 80205382.0 43551154.0 24172201.0 98159963.0 5224938.0 211780824.0 62695489.0 154711438.0 35626958.0 422618.0 6491240.0 54806823.0 752600867.0 415686217.0 27093592.0 34758951.0 152263880.0 32686500.0 6149356.0 310650585.0 4681651.0 215283742.0 9322895.0 3843774.0 56491.0 60331447.0 66984887.0 1214424.0 81126522.0 44723232.0 27293743.0 5341098.0 216485654.0 79628830.0 114984666.0 91720255.0 86855739.0 48668907.0 149411550.0 237382724.0 3875173.0 112462508.0 49843011.0 159291809.0 13348704.0 11514.0 382879.0 7736632.0 134748021.0 89137047.0 55611001.0 101729.0 25147786.0 32054369.0 136333522.0 52844496.0 18689058.0 93251121.0 1754389.0 3494154.0 43053376.0 42059111.0 14788642.0 60321861.0 15089448.0 49050886.0 66166000.0 106956330.0 18409891.0 80547866.0 626396.0 1870392.0 12037973.0 2648195.0 1503830 ...
# Production Company
# Warner Bros. Columbia Pictures Lucasfilm Paramount Pictures Orion Pictures Universal Pictures Chartoff-Winkler Productions Dovemead Films United Artists The Malpaso Company C.A.T. Films Filmways Pictures Rastar Pictures Metro-Goldwyn-Mayer (MGM) IPC Films AVCO Embassy Pictures Lorimar Film Entertainment Partisan Productions Bryna Productions Stephen Friedman/Kings Road Productions ITC Films Twentieth Century Fox Guardian Trust Company Cattle Annie Productions Rastar Films PolyGram Filmed Entertainment Camp Hill EMI Films Walt Disney Productions The South Australian Film Corporation Melvin Simon Productions The Jerry Gross Organization Falcon International Productions Jack Rollins & Charles H. Joffe Productions Opera Film Produzione Tri Star Productions International Cinema Mulberry Square Productions American Cinema Productions Sunn Classic Pictures Major Studio Partners Brooksfilms Mosfilm Braun Entertainment Group Kings Road Entertainment Lee Mendelson Film Productions Alive Enterprises Diversity Music Santa Fe International Borough Park Productions Mike Lobell Productions Time Life Films Les Films Paul Grimault Herb Jaffe Da.Ma. Cinematografica Chuck Barris Productions Broadway Productions F.F. Associates East Asia Film Company The Ladd Company Polygram Pictures Renaissance Pictures Astral Bellevue PathÃ© Charles H. Schneer Productions Cinema '84 Kennedy Miller Productions Bavaria Film Gaumont Golden Harvest Company Mann/Caan Productions HandMade Films Georgetown Productions Inc. Canadian Film Development Corporation (CFDC) Eon Productions Dino De Laurentiis Company Barclays Mercantile Industrial Finance Walt Disney Animation Studios Enigma Productions Saga Productions Inc. Estudios Churubusco Azteca S.A. Aspen Productions (I) Embassy Pictures Gurian Entertainment International Cinema Corporation (ICC) Barry & Enright Productions CIP Filmproduktion GmbH R&R Films Cinema Group Ventures Artista Management Fulvia Film Zoetrope Studios Juniper Films Henson Associates (HA) C & C Brown Production Deliverance Productions Limelight Productions (II) Allen Smithee Classic Films Les Films Galaxie Morison Film Group Innovisions DeHaven/Shapiro Productions Lija Productions Viacom Enterprises Merchant Ivory Productions Baughn/Freed Productions Bakshi Productions Eaves Movie Ranch Lorimar Productions Adams Apple Film Company Jaquet Heron Productions CBS Theatrical Films One Way Productions PolyGram Pictures Calendar International Pictures Balkan Productions Greentree Lupo-Anthony-Quintano Productions Les Films du Losange Anabasis N.V. Cannon Group Incorporated Television Company (ITC) International Film Investors Aurora Embassy International Pictures Leisure Investment Company United Film Distribution Company (UFDC) Cambridge Productions Goldcrest Films International RKO Pictures Cinematograph AB Almena Films Pan Arts Rankin/Bass Productions VAE Productions Sorcerer Productions Golan-Globus Productions The Geffen Company Aspen Film Society The Romantic Venture Chai Productions Byzantine Productions ABC Motion Pictures IndieProd Company Productions Katzka Sandcastle 5 Productions Richmond Light Horse Productions Efer Productions Company Four James Glickenhaus Gray City Jensen Farley Pictures S.F.P.C. Gold Pine Productions Cable and Wireless Finance Bob-Bea Productions Cypress Grove Warner Bros. Animation Frank Yablans Presentations Accent Films B.V. Permut Presentations Regina Ziegler Filmproduktion Alan Enterprises Hanna-Barbera Productions Blustarr Channel Four Film Blueline Productions Adam Packer Film Productions National Lampoon American Eagle Films Unity Productions Atlantic Entertainment Group Filmplan International Amblin Entertainment TaliaFilm II Productions Sherwood Productions Breathless Associates Lucille Ball Productions Marimark Productions Ladbroke Polyc International BV Seagoat Films Celandine Films Rai 2 Edward S. Feldman Productions Aries CinematogrÃ¡fica Argentina Antron Media Production Eagle Associates. 1818 Productio ...
# Runtime
# 146.0 104.0 124.0 88.0 98.0 95.0 133.0 129.0 127.0 100.0 116.0 109.0 114.0 103.0 134.0 89.0 111.0 102.0 219.0 96.0 132.0 115.0 131.0 117.0 92.0 97.0 91.0 101.0 84.0 107.0 99.0 82.0 94.0 173.0 139.0 121.0 123.0 119.0 93.0 150.0 86.0 75.0 106.0 112.0 108.0 83.0 105.0 113.0 85.0 118.0 140.0 149.0 110.0 87.0 126.0 195.0 125.0 122.0 155.0 90.0 167.0 78.0 120.0 191.0 188.0 136.0 128.0 74.0 80.0 170.0 193.0 81.0 77.0 79.0 130.0 55.0 137.0 229.0 160.0 145.0 138.0 141.0 164.0 143.0 153.0 187.0 154.0 162.0 161.0 144.0 72.0 185.0 76.0 163.0 157.0 135.0 357.0 69.0 168.0 171.0 142.0 175.0 181.0 158.0 189.0 238.0 156.0 202.0 182.0 180.0 271.0 71.0 159.0 178.0 192.0 176.0 147.0 242.0 194.0 177.0 169.0 151.0 172.0 148.0 73.0 165.0 186.0 152.0 183.0 224.0 210.0 179.0 201.0 366.0 166.0 nan 63.0 196.0 209.0

# %%
## Review data types again now that we have seen the unique values and determine if any need to be changed? 

# Release date needs to be cleaned to be useful
# Year needs to be converted to Category so it isn't treated like a number

movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
# In looking at the unique values there was a movie with a run time of 366 minites whcih seems like an outlier
# Reviewing the row to get more information
# For now it will be left in --------------------------------------------------
movies_df[movies_df.runtime==366.0]
# Out:
#                    name rating  genre  year               released  score  \
# 4396  The Best of Youth      R  Drama  2003  June 20, 2003 (Italy)    8.5
#
#         votes               director            writer             star  \
# 4396  21000.0  Marco Tullio Giordana  Sandro Petraglia  Luigi Lo Cascio
#
#      country  budget      gross    company  runtime
# 4396   Italy     NaN  2799773.0  BiBi Film    366.0

# %%
## Years is showing as an integer and needs to be converted to a category
movies_df.year=pd.Categorical(movies_df.year)

# %% [markdown]
# #### Does anything else need to be converted to categorical?

# %%
# Check to see if changes took place
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   category
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   category
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: category(2), float64(5), object(8)
# memory usage: 889.3+ KB

# %%
# Display only numeric cloumns
# The describe function provides the count, mean, standard deviation, minimum and maximum values and the quantities of 
# the data.
movies_df.describe().T
# Out:
#           count          mean           std     min         25%         50%  \
# score    7665.0  6.390411e+00  9.688416e-01     1.9         5.8         6.5
# votes    7665.0  8.810850e+04  1.633238e+05     7.0      9100.0     33000.0
# budget   5497.0  3.558988e+07  4.145730e+07  3000.0  10000000.0  20500000.0
# gross    7479.0  7.850054e+07  1.657251e+08   309.0   4532055.5  20205757.0
# runtime  7664.0  1.072616e+02  1.858125e+01    55.0        95.0       104.0
#
#                 75%           max
# score           7.1  9.300000e+00
# votes       93000.0  2.400000e+06
# budget   45000000.0  3.560000e+08
# gross    76016691.5  2.847246e+09
# runtime       116.0  3.660000e+02

# %% [markdown]
# After some addition data exploration we determined that the Years column should be converted to a category
# In looking at the values from the describe function it appears that there are some outliers in all of the numric fields whenyou see the difference between the 75% and the max number

# %%
# Display all cloumns
movies_df.describe(include='all').T

# Look at the difference between 75% and Max for Budget
# Out:
#            count unique                           top  freq             mean  \
# name        7668   7512                        Hamlet     3              NaN
# rating      7591     12                             R  3697              NaN
# genre       7668     19                        Comedy  2245              NaN
# year      7668.0    NaN                           NaN   NaN      2000.405451
# released    7666   3414  May 17, 2019 (United States)     9              NaN
# score     7665.0    NaN                           NaN   NaN         6.390411
# votes     7665.0    NaN                           NaN   NaN     88108.504762
# director    7668   2949                   Woody Allen    38              NaN
# writer      7665   4535                   Woody Allen    37              NaN
# star        7667   2814                  Nicolas Cage    43              NaN
# country     7665     59                 United States  5475              NaN
# budget    5497.0    NaN                           NaN   NaN  35589876.192651
# gross     7479.0    NaN                           NaN   NaN  78500541.017783
# company     7651   2385            Universal Pictures   377              NaN
# runtime   7664.0    NaN                           NaN   NaN       107.261613
#
#                        std     min         25%         50%         75%  \
# name                   NaN     NaN         NaN         NaN         NaN
# rating                 NaN     NaN         NaN         NaN         NaN
# genre                  NaN     NaN         NaN         NaN         NaN
# year             11.153508  1980.0      1991.0      2000.0      2010.0
# released               NaN     NaN         NaN         NaN         NaN
# score             0.968842     1.9         5.8         6.5         7.1
# votes         163323.76391     7.0      9100.0     33000.0     93000.0
# director               NaN     NaN         NaN         NaN         NaN
# writer                 NaN     NaN         NaN         NaN         NaN
# star                   NaN     NaN         NaN         NaN         NaN
# country                NaN     NaN         NaN         NaN         NaN
# budget     41457296.601931  3000.0  10000000.0  20500000.0  45000000.0
# gross     165725124.318757   309.0   4532055.5  20205757.0  76016691.5
# company                NaN     NaN         NaN         NaN         NaN
# runtime          18.581247    55.0        95.0       104.0       116.0
#
#                    max
# name               NaN
# rating             NaN
# genre              NaN
# year            2020.0
# released           NaN
# score              9.3
# votes        2400000.0
# director           NaN
# writer             NaN
# star               NaN
# country            NaN
# budget     356000000.0
# gross     2847246203.0
# company            NaN
# runtime          366.0

# %%
# Lets take a look at the movie with a 356m budget
movies_df[movies_df.budget==356000000.0]
# Out:
#                    name rating   genre  year                        released  \
# 7445  Avengers: Endgame  PG-13  Action  2019  April 26, 2019 (United States)
#
#       score     votes       director              writer               star  \
# 7445    8.4  903000.0  Anthony Russo  Christopher Markus  Robert Downey Jr.
#
#             country       budget         gross         company  runtime
# 7445  United States  356000000.0  2.797501e+09  Marvel Studios    181.0

# %%
# Lets take a look at the movie with a 2 trillion in gross revenue

movies_df[movies_df.gross==2847246203.0]
# Out:
#         name rating   genre  year                           released  score  \
# 5445  Avatar  PG-13  Action  2009  December 18, 2009 (United States)    7.8
#
#           votes       director         writer             star        country  \
# 5445  1100000.0  James Cameron  James Cameron  Sam Worthington  United States
#
#            budget         gross                company  runtime
# 5445  237000000.0  2.847246e+09  Twentieth Century Fox    162.0

# %%
# Display all cloumns
# movies_df.describe(include='all')

# %% [markdown]
# # Correlation Analysis

# %%
# HeatMaps: are a type of plot which is necessary to find the dependent variables. 
# One of the best ways to find the relationship between the features can be done using heat maps

corr=movies_df.corr(method='spearman')
plt.figure(figsize=(15,15))
sn.heatmap(corr,vmax=.8,linewidths=0.01,square=True,annot=True,cmap='YlGn',linecolor='black')

# Below, positive correlation is represented by dark shades and negative correlation by lighter shades.
# shows if one variable influenced by other variable

# Votes influences revenue the most with a positive correlation of .74
# Budget influences revenue the with a positive correlation of .69
# Out:
# <AxesSubplot:>

# %%
# Numerical Representation of the Correlations
corr = movies_df.corr()
corr
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
# plots between independent variable - runtime  and target variable - gross
sn.regplot(x=movies_df.budget, y=movies_df.gross, color='g')
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# plots between independent variable - runtime  and target variable - gross
sn.regplot(x=movies_df.runtime, y=movies_df.gross, color='g')
# Out:
# <AxesSubplot:xlabel='runtime', ylabel='gross'>

# %% [markdown]
# ### Need a comment here on the correlation analysis

# %%
## Analysis of numeric variables

## Function for finding outliers

def findoutliers(column):
    outliers=[]
    Q1=column.quantile(.25)
    Q3=column.quantile(.75)
    IQR=Q3-Q1
    lower_limit=Q1-(1.5*IQR)
    upper_limit=Q3+(1.5*IQR)
    for out1 in column:
        if out1>upper_limit or out1 <lower_limit:
            outliers.append(out1)
            
    return np.array(outliers)  

def plotchart(col):
    fix, (ax1,ax2) =plt.subplots(1,2,figsize=(7,5))
    sn.boxplot(col, orient='v',ax=ax1)
    ax1.set_ylabel=col.name
    ax1.set_title('Box plot of {}'.format(col.name))
    sn.distplot(col,ax=ax2) 
    ax2.set_title('Distribution plot of {}'.format(col.name))
    
def analysis_column(col):
    print('count of outliers ', len(findoutliers(col)))
    print('Mean ',format(col.mean()))
    print('Median ',format(col.median()))
    print('Missing values',format(col.isnull().sum()))
    print('% of Missing values',format(round(100*(col.isnull().sum()/len(col)),2)))
    
    plotchart(col)

# %% [markdown]
# Revenue Analysis

# %%
# Analysis on Revenue
# we know Q3 AND Q1 AND IQR=Q3-Q1, any data point which is less than Q1-1.5IQR or Q3+1.5IQR are consider as outlier
# There seem to be outliers at the upper end of the Gross Revenue

Q1=movies_df.gross.quantile(.25)
Q3=movies_df.gross.quantile(.75)
IQR=Q3-Q1
lower_limit=Q1-(1.5*IQR)
upper_limit=Q3+(1.5*IQR)
print("Min Value",movies_df.gross.min())
print("Max Value ",movies_df.gross.max())
print("Q1 ",Q1)
print("Q3 ",Q3)
print("IQR ",IQR)
print('lower_limit',lower_limit)
print('upper_limit',upper_limit)
# Out:
# Min Value 309.0
# Max Value  2847246203.0
# Q1  4532055.5
# Q3  76016691.5
# IQR  71484636.0
# lower_limit -102694898.5
# upper_limit 183243645.5

# %%
# Revenue Analysis and Individual metric to look for outliers and distribution of data
analysis_column(movies_df.gross)
# Out:
# count of outliers  851
# Mean  78500541.01778312
# Median  20205757.0
# Missing values 189
# % of Missing values 2.46

# %%
# Gross Histogram — refers to the frequency of occurrence of variables in an interval.
movies_df.gross.hist()
# Out:
# <AxesSubplot:>

# %%
# Revenue vs # of Movies
ax_revenue = sns.distplot(movies_df.gross,kde=False)
ax_revenue.set_title('Revenue vs Number of Movies')
ax_revenue.set_xlabel('Revenue')
ax_revenue.set_ylabel('Number of Movies')
#plt.savefig("revenue_vs_number_of_movies.png")
# Out:
# Text(0, 0.5, 'Number of Movies')

# %% [markdown]
# Budget Analysis

# %%
# Analysis on Budget
# we know Q3 AND Q1 AND IQR=Q3-Q1, any data point which is less than Q1-1.5IQR or Q3+1.5IQR are consider as outlier
# There seem to be outliers at the upper end of the budget

Q1=movies_df.budget.quantile(.25)
Q3=movies_df.budget.quantile(.75)
IQR=Q3-Q1
lower_limit=Q1-(1.5*IQR)
upper_limit=Q3+(1.5*IQR)
print("Min Value",movies_df.budget.min())
print("Max Value ",movies_df.budget.max())
print("Q1 ",Q1)
print("Q3 ",Q3)
print("IQR ",IQR)
print('lower_limit',lower_limit)
print('upper_limit',upper_limit)
# Out:
# Min Value 3000.0
# Max Value  356000000.0
# Q1  10000000.0
# Q3  45000000.0
# IQR  35000000.0
# lower_limit -42500000.0
# upper_limit 97500000.0

# %%
# Budget Analysis and Individual metric to look for outliers and distribution of data
analysis_column(movies_df.budget)
# Out:
# count of outliers  445
# Mean  35589876.192650534
# Median  20500000.0
# Missing values 2171
# % of Missing values 28.31

# %%
movies_df.budget.hist()
# Histogram — refers to the frequency of occurrence of variables in an interval.
# Out:
# <AxesSubplot:>

# %% [markdown]
# Runtime Analysis

# %%
# Analysis on Runtime
# we know Q3 AND Q1 AND IQR=Q3-Q1, any data point which is less than Q1-1.5IQR or Q3+1.5IQR are consider as outlier

Q1=movies_df.runtime.quantile(.25)
Q3=movies_df.runtime.quantile(.75)
IQR=Q3-Q1
lower_limit=Q1-(1.5*IQR)
upper_limit=Q3+(1.5*IQR)
print("Min Value",movies_df.runtime.min())
print("Max Value ",movies_df.runtime.max())
print("Q1 ",Q1)
print("Q3 ",Q3)
print("IQR ",IQR)
print('lower_limit',lower_limit)
print('upper_limit',upper_limit)
# Out:
# Min Value 55.0
# Max Value  366.0
# Q1  95.0
# Q3  116.0
# IQR  21.0
# lower_limit 63.5
# upper_limit 147.5

# %%
# Analysis and Individual metric to look for outliers and distribution of data
analysis_column(movies_df.runtime)
# Out:
# count of outliers  240
# Mean  107.2616127348643
# Median  104.0
# Missing values 4
# % of Missing values 0.05

# %%
# Runtime Histogram — refers to the frequency of occurrence of variables in an interval.
movies_df.runtime.hist()
# Out:
# <AxesSubplot:>

# %%
# Analysis on Votes
# we know Q3 AND Q1 AND IQR=Q3-Q1, any data point which is less than Q1-1.5IQR or Q3+1.5IQR are consider as outlier

Q1=movies_df.votes.quantile(.25)
Q3=movies_df.votes.quantile(.75)
IQR=Q3-Q1
lower_limit=Q1-(1.5*IQR)
upper_limit=Q3+(1.5*IQR)
print("Min Value",movies_df.votes.min())
print("Max Value ",movies_df.votes.max())
print("Q1 ",Q1)
print("Q3 ",Q3)
print("IQR ",IQR)
print('lower_limit',lower_limit)
print('upper_limit',upper_limit)
# Out:
# Min Value 7.0
# Max Value  2400000.0
# Q1  9100.0
# Q3  93000.0
# IQR  83900.0
# lower_limit -116750.0
# upper_limit 218850.0

# %%
# Analysis and Individual metric to look for outliers and distribution of data
analysis_column(movies_df.votes)
# Out:
# count of outliers  803
# Mean  88108.50476190477
# Median  33000.0
# Missing values 3
# % of Missing values 0.04

# %%
# Analysis on Score
# we know Q3 AND Q1 AND IQR=Q3-Q1, any data point which is less than Q1-1.5IQR or Q3+1.5IQR are consider as outlier

Q1=movies_df.score.quantile(.25)
Q3=movies_df.score.quantile(.75)
IQR=Q3-Q1
lower_limit=Q1-(1.5*IQR)
upper_limit=Q3+(1.5*IQR)
print("Min Value",movies_df.score.min())
print("Max Value ",movies_df.score.max())
print("Q1 ",Q1)
print("Q3 ",Q3)
print("IQR ",IQR)
print('lower_limit',lower_limit)
print('upper_limit',upper_limit)
# Out:
# Min Value 1.9
# Max Value  9.3
# Q1  5.8
# Q3  7.1
# IQR  1.2999999999999998
# lower_limit 3.85
# upper_limit 9.049999999999999

# %%
print(len(findoutliers(movies_df.score))) # of rows having outlier
# Out:
# 119

# %%
# Analysis and Individual metric to look for outliers and distribution of data
analysis_column(movies_df.score)
# Out:
# count of outliers  119
# Mean  6.390410958904098
# Median  6.5
# Missing values 3
# % of Missing values 0.04

# %% [markdown]
# ### Histogram  Visualizations

# %%
# Using Histograms to to check for outliers in numerical columns
bins = len(movies_df)
plt.figure(figsize=(15, 6))

plt.subplot(1, 3, 1)
plt.hist(movies_df.budget, bins=20)
plt.title('budget')

plt.subplot(1, 3, 2)
plt.hist(movies_df.gross, bins=20)
plt.title('gross')

plt.subplot(1, 3, 3)
plt.hist(movies_df.runtime, bins=20)
plt.title('runtime')


plt.show()

# %% [markdown]
# Most Movies had a budget below 100M Budgets, Revenue below 200M and a Runtime between 75 and 160 min
# Should movies with extreme outliers in one of these categories be dropped?
# Leaving in for now...

# %% [markdown]
# ## Categorical Analysis

# %%
movies_df.star.value_counts()
# Out:
# Nicolas Cage         43
# Tom Hanks            41
# Robert De Niro       41
# Denzel Washington    37
# Bruce Willis         34
#                      ..
# Jena Malone           1
# Jemma Dallender       1
# Jemaine Clement       1
# Jeffrey Falcon        1
# Ãmilie Dequenne      1
# Name: star, Length: 2814, dtype: int64

# %%
# in percentage
movies_df.star.value_counts(normalize=True)
# that Nicolas Cage is .56%
# Out:
# Nicolas Cage         0.005608
# Tom Hanks            0.005348
# Robert De Niro       0.005348
# Denzel Washington    0.004826
# Bruce Willis         0.004435
#                        ...
# Jena Malone          0.000130
# Jemma Dallender      0.000130
# Jemaine Clement      0.000130
# Jeffrey Falcon       0.000130
# Ãmilie Dequenne     0.000130
# Name: star, Length: 2814, dtype: float64

# %%
# Bar plot for Star Category  - #too many to see something usefull here
# sn.factorplot('star',data=movies_df,kind='count')

# %%
movies_df.director.value_counts()
# Out:
# Woody Allen         38
# Clint Eastwood      31
# Directors           28
# Steven Spielberg    27
# Ron Howard          24
#                     ..
# Lance Mungia         1
# Daniel Myrick        1
# Andy Wilson          1
# Sean Mewshaw         1
# Gilbert Adler        1
# Name: director, Length: 2949, dtype: int64

# %%
# in percentage
movies_df.director.value_counts(normalize=True)
# Out:
# Woody Allen         0.004956
# Clint Eastwood      0.004043
# Directors           0.003652
# Steven Spielberg    0.003521
# Ron Howard          0.003130
#                       ...
# Lance Mungia        0.000130
# Daniel Myrick       0.000130
# Andy Wilson         0.000130
# Sean Mewshaw        0.000130
# Gilbert Adler       0.000130
# Name: director, Length: 2949, dtype: float64

# %%
# Bar plot for Director Category  - #too many to see something usefull here
# sn.factorplot('director',data=movies_df,kind='count')

# %%
movies_df.writer.value_counts()
# Out:
# Woody Allen            37
# Stephen King           31
# Luc Besson             26
# John Hughes            25
# William Shakespeare    15
#                        ..
# Judd Klinger            1
# Ruth Avergon            1
# Court Crandall          1
# Elliott Lewitt          1
# Daryl Matthews          1
# Name: writer, Length: 4535, dtype: int64

# %% [markdown]
# #### for actors / directors  should we groups the low volumes together?

# %%
# in percentage
movies_df.writer.value_counts(normalize=True)
# Out:
# Woody Allen            0.004827
# Stephen King           0.004044
# Luc Besson             0.003392
# John Hughes            0.003262
# William Shakespeare    0.001957
#                          ...
# Judd Klinger           0.000130
# Ruth Avergon           0.000130
# Court Crandall         0.000130
# Elliott Lewitt         0.000130
# Daryl Matthews         0.000130
# Name: writer, Length: 4535, dtype: float64

# %%
movies_df.company.value_counts()
# Out:
# Universal Pictures               377
# Warner Bros.                     334
# Columbia Pictures                332
# Paramount Pictures               320
# Twentieth Century Fox            240
#                                 ...
# Channel Films                      1
# Astralwerks                        1
# Reteitalia                         1
# Blank of the Dead Productions      1
# ATO Pictures                       1
# Name: company, Length: 2385, dtype: int64

# %%
# in percentage
movies_df.company.value_counts(normalize=True)
# Out:
# Universal Pictures               0.049275
# Warner Bros.                     0.043654
# Columbia Pictures                0.043393
# Paramount Pictures               0.041825
# Twentieth Century Fox            0.031368
#                                    ...
# Channel Films                    0.000131
# Astralwerks                      0.000131
# Reteitalia                       0.000131
# Blank of the Dead Productions    0.000131
# ATO Pictures                     0.000131
# Name: company, Length: 2385, dtype: float64

# %%
# sn.factorplot('company',data=movies_df,kind='count')  # not very helpful

# %%
# Count the number of movies per year  --- looks like 200 is the cap
movies_df.year.value_counts()
# Out:
# 2000    200
# 2009    200
# 2002    200
# 2003    200
# 2004    200
# 2005    200
# 2006    200
# 2007    200
# 2008    200
# 2010    200
# 2019    200
# 2011    200
# 2012    200
# 2013    200
# 2014    200
# 2015    200
# 2016    200
# 2017    200
# 2001    200
# 1999    200
# 1990    200
# 1991    200
# 1985    200
# 1986    200
# 1987    200
# 1988    200
# 1989    200
# 1998    200
# 2018    200
# 1992    200
# 1993    200
# 1994    200
# 1995    200
# 1996    200
# 1997    200
# 1984    168
# 1983    144
# 1982    126
# 1981    113
# 1980     92
# 2020     25
# Name: year, dtype: int64

# %%
#Plot the numbers of movies released per year

pl = sn.factorplot('year',data=movies_df, aspect=4,kind='count')
pl.set_xticklabels(step=5)

# %%
#Revenue compared to release date

mean_year = movies_df.groupby('year').mean().reset_index()
sns.set()
_=mean_year.plot.bar(x='year', y='gross', color='green', figsize=(14, 10))
_=plt.xlabel('Year')
_=plt.ylabel('Average Revenue ($10M)')
_=plt.title('Average Revenue vs. Year of release')

# %% [markdown]
# The Graph is showing a increase in movies revenue from 1980 to 2020.
# What is causing this?  More Movie theaters? Increase in Rate? More people going to moves?

# %%
movies_df["genre"].unique()
# Out:
# array(['Drama', 'Adventure', 'Action', 'Comedy', 'Horror', 'Biography',
#        'Crime', 'Fantasy', 'Family', 'Sci-Fi', 'Animation', 'Romance',
#        'Music', 'Western', 'Thriller', 'History', 'Mystery', 'Sport',
#        'Musical'], dtype=object)

# %%
plt.figure(figsize=(15,10))
sns.countplot(x = movies_df["genre"])
plt.show()

# %% [markdown]
# 19 unique Genre,
# Comedies having the larges number of movies in the dataset, followed by Action and then Drama
# These 3 make up more than 50% of all the movies in the dataset

# %% [markdown]
# # Data Relationships

# %%
# look at relationships between Categories and Revenue
movies_df_strings = movies_df.loc[:, ['company', 'country', 'director', 'genre', 'name', 'rating', 'star', 'writer']]
catgs = {}
for i in list(movies_df_strings.columns):
    catgs[i] = movies_df_strings[i].nunique()
    
catgs
# Out:
# {'company': 2385,
#  'country': 59,
#  'director': 2949,
#  'genre': 19,
#  'name': 7512,
#  'rating': 12,
#  'star': 2814,
#  'writer': 4535}

# %% [markdown]
# Some Categories have too many values to bar plot - company, director, name, star and writer

# %%
# Average Revenue vs Country of Release
movies_df.groupby('country').mean().reset_index().sort_values('gross').plot.bar(x='country', y='gross', figsize=(17,10), color='g')
plt.xlabel('Country')
plt.ylabel('Average Revenue ($10M)')
plt.title('Average Revenue vs. Country of Release')
# Out:
# Text(0.5, 1.0, 'Average Revenue vs. Country of Release')

# %% [markdown]
# Finland, China, New Zealand adn Malta have the Highest average revenue per release

# %%
# Average Revenue vs Country of Release
movies_df.groupby('genre').mean().reset_index().sort_values('gross').plot.bar(x='genre', y='gross', figsize=(17,10), color='g')
plt.xlabel('Genre')
plt.ylabel('Average Revenue ($10M)')
plt.title('Average Revenue vs. Genre')
# Out:
# Text(0.5, 1.0, 'Average Revenue vs. Genre')

# %% [markdown]
# Animation has the highest average among the different Genre, followed by Family and Action.

# %%
# Genre of movies and Revenue - Box Plot
plt.figure(figsize=(16, 6))
sns.boxplot(x='genre', y='gross', data=movies_df.sort_values('gross', ascending=False))
plt.xlabel('Genre')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.title('Revenue vs. Genre of Movie')
# Out:
# Text(0.5, 1.0, 'Revenue vs. Genre of Movie')

# %%
# Scatter PLot - Revenue vs Budget

movies_df.plot.scatter(x='budget', y='gross', figsize=(10, 5))
plt.xlabel('Budget ($100M)')
plt.ylabel('Revenue ($100M)')
plt.title('Budget vs. Revenue')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# Text(0.5, 1.0, 'Budget vs. Revenue')

# %% [markdown]
# This shows a somewhat linear relationship between gross revenue and budget which is not suprise.
# One could assume the more you spend to make a movie the more revenue it might make.

# %%
# Distribution Histogram
movies_df.hist(bins=50,figsize=(17,17))
plt.show()

# %%
# Distibution - Density
movies_df.plot(kind='density', subplots=True, layout=(3,3), sharex=False, sharey=False,fontsize=10, figsize = (16, 16))
plt.show()

# %% [markdown]
# Most Variables seem to be right skewed or positive in relation to our target variable of Gross Revenue
# Score seems to be normally distributed

# %%
# Box Plot
movies_df.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False,fontsize=8, figsize = (15, 15))
plt.show()

# %%
# Scatter Matrix
sns.pairplot(movies_df,height=3) # scatter matrix
plt.show()

# %% [markdown]
# Looks to be outliers in all features.

# %%
# SCatter of just Gross vs Budget
plt.scatter(movies_df["gross"],movies_df["budget"])
plt.xlabel("Gross Revenue")
plt.ylabel("Budget")
# Out:
# Text(0, 0.5, 'Budget')

# %% [markdown]
# ### Analyzing Catagorical Values
